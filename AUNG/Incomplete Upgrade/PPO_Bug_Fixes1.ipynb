# %%
import pandas as pd
import yfinance as yf
import ta
import pandas_datareader.data as web
import numpy as np
import torch
import quantstats as qs
import os
import json
import warnings

warnings.filterwarnings('ignore')

from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback

# %%
# ==========================================
# 0. HARDWARE SETUP
# ==========================================
device = "cpu"
print(f"✅ Device Strategy: '{device}' เพราะ PPO+MlpPolicy เป็นโมเดลเล็ก การใช้ GPU จะช้ากว่าเพราะ overhead การส่งข้อมูล")
if torch.cuda.is_available():
    print(f"   - พบ GPU: {torch.cuda.get_device_name(0)} (แต่ไม่แนะนำให้ใช้กับ PPO MlpPolicy)")
else:
    print("   - ไม่พบการ์ดจอแยก ระบบจะทำงานบน CPU (เหมาะสมอยู่แล้วสำหรับโปรเจกต์นี้)")
# Out:
# ✅ Device Strategy: 'cpu' เพราะ PPO+MlpPolicy เป็นโมเดลเล็ก การใช้ GPU จะช้ากว่าเพราะ overhead การส่งข้อมูล
#    - พบ GPU: NVIDIA GeForce RTX 5060 Ti (แต่ไม่แนะนำให้ใช้กับ PPO MlpPolicy)

# %%
# ==========================================
# 1. GLOBAL CONFIGURATION
# ==========================================
TICKERS = ['DIA', 'QQQ', 'SPY']
TRANSACTION_COST_PCT = 0.015  
FED_FUNDS_LAG_DAYS = 30   
M2_LAG_DAYS = 60 # แก้ไข #5: ปรับเป็น 60 วันเพื่อให้สมจริงตามรอบการประกาศของ FED

USE_MULTI_TIMEFRAME = False

COMPLETE_TECHNICAL_INDICATORS = [
    'RSI_14', 'RSI_signal', 'RSI_overbought', 'RSI_oversold', 'RSI_above_center',
    'MACD_line', 'MACD_signal', 'MACD_histogram', 'MACD_cross',
    'EMA_12', 'EMA_26', 'EMA_50', 'EMA_200',
    'price_to_EMA50_ratio', 'price_to_EMA200_ratio',
    'EMA_golden_cross', 'EMA_death_cross',
    'StochRSI_K', 'StochRSI_D', 'StochRSI_cross',
]

MULTI_TIMEFRAME_INDICATORS = [
    'RSI_weekly', 'RSI_monthly',
    'MACD_histogram_weekly', 'MACD_histogram_monthly',
]

MACRO_INDICATORS = ['vix', 'bond_yield', 'gold', 'wti', 'fed_rate', 'm2']

TECHNICAL_INDICATORS = COMPLETE_TECHNICAL_INDICATORS + (
    MULTI_TIMEFRAME_INDICATORS if USE_MULTI_TIMEFRAME else []
)
FEATURES = TECHNICAL_INDICATORS + MACRO_INDICATORS

# %%
# ==========================================
# 2. INDICATOR COMPUTATION 
# ==========================================
def compute_complete_indicators(df, price_col='close'):
    close = df[price_col]

    rsi = ta.momentum.RSIIndicator(close=close, window=14).rsi()
    df['RSI_14'] = rsi
    df['RSI_signal'] = rsi.rolling(window=9).mean()
    df['RSI_overbought'] = (rsi > 70).astype(float)
    df['RSI_oversold'] = (rsi < 30).astype(float)
    df['RSI_above_center'] = (rsi > 50).astype(float)

    macd_obj = ta.trend.MACD(close=close, window_slow=26, window_fast=12, window_sign=9)
    macd_line = macd_obj.macd()
    macd_signal = macd_obj.macd_signal()
    df['MACD_line'] = macd_line
    df['MACD_signal'] = macd_signal
    df['MACD_histogram'] = macd_obj.macd_diff()
    prev_diff = (macd_line - macd_signal).shift(1)
    curr_diff = macd_line - macd_signal
    df['MACD_cross'] = np.select(
        [(prev_diff <= 0) & (curr_diff > 0), (prev_diff >= 0) & (curr_diff < 0)],
        [1.0, -1.0], default=0.0
    )

    ema12 = ta.trend.EMAIndicator(close=close, window=12).ema_indicator()
    ema26 = ta.trend.EMAIndicator(close=close, window=26).ema_indicator()
    ema50 = ta.trend.EMAIndicator(close=close, window=50).ema_indicator()
    ema200 = ta.trend.EMAIndicator(close=close, window=200).ema_indicator()
    df['EMA_12'] = ema12
    df['EMA_26'] = ema26
    df['EMA_50'] = ema50
    df['EMA_200'] = ema200
    df['price_to_EMA50_ratio'] = (close - ema50) / ema50
    df['price_to_EMA200_ratio'] = (close - ema200) / ema200
    prev_ema_diff = (ema50 - ema200).shift(1)
    curr_ema_diff = ema50 - ema200
    df['EMA_golden_cross'] = ((prev_ema_diff <= 0) & (curr_ema_diff > 0)).astype(float)
    df['EMA_death_cross'] = ((prev_ema_diff >= 0) & (curr_ema_diff < 0)).astype(float)

    stochrsi_obj = ta.momentum.StochRSIIndicator(close=close, window=14, smooth1=3, smooth2=3)
    stoch_k = stochrsi_obj.stochrsi_k()
    stoch_d = stochrsi_obj.stochrsi_d()
    df['StochRSI_K'] = stoch_k
    df['StochRSI_D'] = stoch_d
    prev_stoch_diff = (stoch_k - stoch_d).shift(1)
    curr_stoch_diff = stoch_k - stoch_d
    bullish_cross = (prev_stoch_diff <= 0) & (curr_stoch_diff > 0) & (stoch_k < 0.2)
    bearish_cross = (prev_stoch_diff >= 0) & (curr_stoch_diff < 0) & (stoch_k > 0.8)
    df['StochRSI_cross'] = np.select([bullish_cross, bearish_cross], [1.0, -1.0], default=0.0)

    return df

def compute_multi_timeframe_features(df, price_col='close', date_col='date'):
    df = df.copy()
    df[date_col] = pd.to_datetime(df[date_col])
    df = df.set_index(date_col).sort_index()
    close = df[price_col]

    weekly_close = close.resample('W-FRI').last()
    weekly_rsi = ta.momentum.RSIIndicator(close=weekly_close, window=14).rsi().shift(1)
    df['RSI_weekly'] = weekly_rsi.reindex(df.index, method='ffill')

    weekly_macd_hist = ta.trend.MACD(close=weekly_close).macd_diff().shift(1)
    df['MACD_histogram_weekly'] = weekly_macd_hist.reindex(df.index, method='ffill')

    monthly_close = close.resample('ME').last()
    monthly_rsi = ta.momentum.RSIIndicator(close=monthly_close, window=14).rsi().shift(1)
    df['RSI_monthly'] = monthly_rsi.reindex(df.index, method='ffill')

    monthly_macd_hist = ta.trend.MACD(close=monthly_close).macd_diff().shift(1)
    df['MACD_histogram_monthly'] = monthly_macd_hist.reindex(df.index, method='ffill')

    df = df.reset_index()
    return df

# %%
# ==========================================
# 3. HIGH-PERFORMANCE DATA PIPELINE
# ==========================================
def fetch_and_prepare_data(tickers, start_date, end_date, warmup_calendar_days=290):
    # แก้ไข #3: ถอยหลังดึงข้อมูลล่วงหน้าเพื่อเตรียมพร้อมให้ Indicator อย่าง EMA_200 
    buffer_start = (pd.to_datetime(start_date) - pd.Timedelta(days=warmup_calendar_days)).strftime('%Y-%m-%d')
    print(f"📦 กําลังดาวน์โหลดข้อมูลจาก {start_date} ถึง {end_date} (ดึงเผื่อ Buffer ตั้งแต่ {buffer_start})...")
    processed_dfs = []

    for ticker in tickers:
        try:
            df = yf.download(ticker, start=buffer_start, end=end_date, progress=False)
            if df.empty:
                continue

            df.columns = [col[0] if isinstance(col, tuple) else col for col in df.columns]
            df = df.reset_index()
            df.rename(columns={'Date': 'date', 'Open': 'open', 'High': 'high', 'Low': 'low',
                                'Close': 'close', 'Volume': 'volume'}, inplace=True)
            df['tic'] = ticker
            df = compute_complete_indicators(df, price_col='close')

            if USE_MULTI_TIMEFRAME:
                df = compute_multi_timeframe_features(df, price_col='close', date_col='date')

            processed_dfs.append(df)
        except Exception as e:
            print(f"❌ ไม่สามารถดาวน์โหลด {ticker}: {e}")

    if not processed_dfs:
        raise ValueError("ดาวน์โหลดข้อมูลล้มเหลว กรุณาตรวจสอบการเชื่อมต่ออินเทอร์เน็ต")

    final_df = pd.concat(processed_dfs, ignore_index=True)

    macro_tickers = {"^VIX": "vix", "^TNX": "bond_yield", "GC=F": "gold", "CL=F": "wti"}
    try:
        macro_raw = yf.download(list(macro_tickers.keys()), start=buffer_start, end=end_date, progress=False)
        macro_df = macro_raw['Close'].copy()
        macro_df.columns = [col[0] if isinstance(col, tuple) else col for col in macro_df.columns]
        macro_df.rename(columns=macro_tickers, inplace=True)
        macro_df = macro_df.reset_index().rename(columns={'Date': 'date'})
        final_df = pd.merge(final_df, macro_df, on='date', how='left')
    except Exception as e:
        for name in macro_tickers.values():
            final_df[name] = np.nan

    try:
        fed_funds = web.DataReader('FEDFUNDS', 'fred', buffer_start, end_date).reset_index()
        m2_supply = web.DataReader('M2SL', 'fred', buffer_start, end_date).reset_index()

        fed_funds.rename(columns={'DATE': 'date', 'FEDFUNDS': 'fed_rate'}, inplace=True)
        m2_supply.rename(columns={'DATE': 'date', 'M2SL': 'm2'}, inplace=True)

        fed_funds['date'] = pd.to_datetime(fed_funds['date']) + pd.Timedelta(days=FED_FUNDS_LAG_DAYS)
        m2_supply['date'] = pd.to_datetime(m2_supply['date']) + pd.Timedelta(days=M2_LAG_DAYS)

        # แก้ไข #5: เปลี่ยนไปใช้ merge_asof เพื่ออุดช่องโหว่วันหยุดเสาร์-อาทิตย์
        final_df['date'] = pd.to_datetime(final_df['date'])
        final_df.sort_values('date', inplace=True)
        fed_funds.sort_values('date', inplace=True)
        m2_supply.sort_values('date', inplace=True)

        final_df = pd.merge_asof(final_df, fed_funds, on='date', direction='backward')
        final_df = pd.merge_asof(final_df, m2_supply, on='date', direction='backward')
    except Exception as e:
        print(f"⚠️ ดึงข้อมูล FRED ไม่สำเร็จ: {e}")
        final_df['fed_rate'] = np.nan
        final_df['m2'] = np.nan

    final_df.sort_values(['date', 'tic'], inplace=True)
    final_df = final_df.groupby('tic', group_keys=False).apply(lambda g: g.ffill())

    if USE_MULTI_TIMEFRAME:
        for col in MULTI_TIMEFRAME_INDICATORS:
            if col in final_df.columns:
                final_df[col] = final_df[col].fillna(0.0)

    final_df.dropna(inplace=True)

    # ตัดข้อมูลกลับมาเริ่มที่ start_date ที่แท้จริง (ทิ้งส่วน Buffer ป้องกัน Leakage)
    final_df = final_df[final_df['date'] >= pd.to_datetime(start_date)].reset_index(drop=True)

    date_list = sorted(final_df['date'].unique())
    date2day = {date: day for day, date in enumerate(date_list)}
    final_df['day'] = final_df['date'].map(date2day)
    final_df['date'] = final_df['date'].dt.strftime('%Y-%m-%d')

    final_df = final_df.sort_values(['date', 'tic'])
    final_df.index = final_df['day'].values
    return final_df

def compute_macro_scaling_stats(train_df):
    scale_cols = ['m2', 'fed_rate', 'vix', 'bond_yield', 'gold', 'wti']
    stats = {}
    for col in scale_cols:
        if col in train_df.columns:
            mean = train_df[col].mean()
            std = train_df[col].std()
            std = std if std > 1e-8 else 1.0
            stats[col] = (mean, std)
    return stats

def apply_macro_scaling(df, stats):
    df = df.copy()
    for col, (mean, std) in stats.items():
        if col in df.columns:
            df[col] = (df[col] - mean) / std
    return df

# %%
# ==========================================
# 4. ROBUST CUSTOM ENVIRONMENT
# ==========================================
class RealisticTradingEnv(StockTradingEnv):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        # แก้ไข #2: ให้ Index ของ VIX ตรงกับวันที่แท้จริงบน format ของ FinRL
        if 'vix' in self.df.columns:
            self.vix_array = self.df.groupby(self.df.index)['vix'].first().sort_index().values
        else:
            self.vix_array = np.zeros(len(self.df.index.unique()))
        
        # ตัวแปรเสริมสำหรับเก็บ Cost ณ step ที่แล้ว
        self._prev_cost = 0.0

    def reset(self, **kwargs):
        obs, info = super().reset(**kwargs)
        self._prev_cost = 0.0
        return obs, info

    # แก้ไข #1: Override step() เพื่อให้ environment ใช้งาน Custom Reward
    def step(self, actions):
        state, reward, terminal, truncated, info = super().step(actions)
        if not terminal:
            reward = self._calculate_reward()
            self.reward = reward
            if len(self.rewards_memory) > 0:
                self.rewards_memory[-1] = reward
        return state, reward, terminal, truncated, info

    def _calculate_reward(self):
        current_portfolio_value = self.state[0] + sum(
            np.array(self.state[1:(self.stock_dim + 1)]) *
            np.array(self.state[(self.stock_dim + 1):(self.stock_dim * 2 + 1)])
        )

        previous_portfolio_value = self.asset_memory[-1] if len(self.asset_memory) > 0 else self.initial_amount
        if previous_portfolio_value <= 0:
            previous_portfolio_value = self.initial_amount

        step_return = (current_portfolio_value - previous_portfolio_value) / previous_portfolio_value
        
        # แก้ไข #4: คำนวณ Transaction Cost เฉพาะใน step ล่าสุด
        cost_this_step = self.cost - self._prev_cost
        self._prev_cost = self.cost
        transaction_costs = cost_this_step * self.reward_scaling

        if step_return < 0:
            step_return *= 2.0

        current_vix = self.vix_array[self.day] if self.day < len(self.vix_array) else 0.0
        invested_ratio = 1 - (self.state[0] / current_portfolio_value) if current_portfolio_value > 0 else 0

        risk_penalty = 0.0
        if current_vix > 0.0:
            vix_excess = current_vix / 10.0
            risk_penalty = vix_excess * invested_ratio * (abs(step_return) + 0.001)

        raw_reward = (step_return * 100) - transaction_costs - (risk_penalty * 100)
        reward = 10.0 * np.tanh(raw_reward / 10.0)

        return float(reward)

def get_env_kwargs(stock_dimension):
    state_space = 1 + (2 * stock_dimension) + (len(FEATURES) * stock_dimension)
    return {
        "hmax": 100,
        "initial_amount": 1000000,
        "num_stock_shares": [0] * stock_dimension,
        "state_space": state_space,
        "stock_dim": stock_dimension,
        "tech_indicator_list": FEATURES,
        "action_space": stock_dimension,
        "reward_scaling": 1e-4,
        "buy_cost_pct": [TRANSACTION_COST_PCT] * stock_dimension,
        "sell_cost_pct": [TRANSACTION_COST_PCT] * stock_dimension,
    }

# %%
# ==========================================
# 5. TRANSLATION & REPORT ENGINE
# ==========================================
def explain_bot_performance(returns):
    print("\n" + "=" * 55)
    print("🤖 สรุปผลงานบอทเทรดในหน้าต่างทดสอบจริง (ฉบับเข้าใจง่าย)")
    print("=" * 55)

    total_return = qs.stats.comp(returns) * 100
    cagr = qs.stats.cagr(returns) * 100
    max_dd = qs.stats.max_drawdown(returns) * 100
    sharpe = qs.stats.sharpe(returns)
    win_rate = qs.stats.win_rate(returns) * 100

    print("\n💰 1. ด้านการทำกำไร (Return)")
    print(f"   • กำไรสะสมตลอดการทดสอบ: {total_return:.2f}%")
    print(f"   • ผลตอบแทนทบต้นเฉลี่ยรายปี (CAGR): {cagr:.2f}%")
    if cagr > 12:
        print("   ✅ สรุป: ยอดเยี่ยม! บอทสร้างผลงานชนะอัตราเฉลี่ยของตลาดส่วนใหญ่")
    elif cagr > 0:
        print("   ⚠️ สรุป: พอใช้ได้ พอร์ตโตขึ้นแต่ยังไม่โดดเด่นนัก")
    else:
        print("   ❌ สรุป: ล้มเหลว บอททำเงินต้นสูญหาย")

    print("\n📉 2. ด้านความเสี่ยง (Risk & Drawdown)")
    print(f"   • ช่วงที่พอร์ตร่วงหนักสุดจากจุดสูงสุด (Max Drawdown): {max_dd:.2f}%")
    if max_dd > -15:
        print("   ✅ สรุป: ปลอดภัยสูง ระบบคุมสัดส่วนการสูญเสียเงินได้ดีมาก")
    elif max_dd > -30:
        print("   ⚠️ สรุป: ปานกลาง พอร์ตแกว่งตามมาตรฐานสไตล์กองทุนเชิงรุก")
    else:
        print("   ❌ สรุป: อันตรายมาก! บอทปล่อยให้พอร์ตเสียหายหนักเกินไป")

    print("\n⚖️ 3. ความคุ้มค่าและสถิติการชนะ (Efficiency)")
    print(f"   • ความคุ้มค่าต่อหนึ่งหน่วยความเสี่ยง (Sharpe Ratio): {sharpe:.2f}")
    if sharpe >= 1.0:
        print("   ✅ สรุป: ดีเยี่ยม กำไรที่ได้คุ้มค่าอย่างมากกับความเสี่ยงที่ถือครอง")
    else:
        print("   ⚠️ สรุป: ความคุ้มค่าน้อยลง ผลตอบแทนอาจไม่สมน้ำสมเนื้อกับความเสี่ยงที่เผชิญ")
    print(f"   • อัตราความแม่นยำรายวัน (Win Rate): {win_rate:.2f}%")
    print("=" * 55 + "\n")

# %%
# ==========================================
# 6. HIGH-SPEED TRAINING PIPELINE WITH VALIDATION
# ==========================================
def train_model():
    TRAIN_START, TRAIN_END = '1999-04-01', '2019-12-31'
    VAL_START, VAL_END = '2020-01-01', '2023-12-31'

    os.makedirs("./exported_data", exist_ok=True)

    print(f"\nℹ️ Feature ทั้งหมดที่ใช้ ({len(FEATURES)} ตัว): {FEATURES}")
    print(f"ℹ️ Multi-timeframe: {'เปิดใช้งาน' if USE_MULTI_TIMEFRAME else 'ปิดอยู่ (ตั้ง USE_MULTI_TIMEFRAME=True เพื่อเปิด)'}")

    print("\n--- 🛠️ [1/3] เริ่มเตรียมข้อมูลสําหรับฝึกสอนบอท (Training Set) ---")
    train_df = fetch_and_prepare_data(TICKERS, TRAIN_START, TRAIN_END)

    print("\n--- 🛠️ [2/3] เริ่มเตรียมข้อมูลสําหรับข้อสอบ (Validation Set) ---")
    val_df = fetch_and_prepare_data(TICKERS, VAL_START, VAL_END)

    scaling_stats = compute_macro_scaling_stats(train_df)
    train_df = apply_macro_scaling(train_df, scaling_stats)
    val_df = apply_macro_scaling(val_df, scaling_stats)

    with open("./exported_data/macro_scaling_stats.json", "w") as f:
        json.dump({k: list(v) for k, v in scaling_stats.items()}, f)

    train_df.to_csv("./exported_data/train_set.csv", index=False)
    val_df.to_csv("./exported_data/validation_set.csv", index=False)
    print("📁 [Exported] บันทึกไฟล์ Training/Validation Set และสถิติ Scaling เรียบร้อย")

    env_kwargs = get_env_kwargs(len(TICKERS))

    def make_env():
        return lambda: RealisticTradingEnv(df=train_df, **env_kwargs)

    NUM_CPU = 4
    env_train = SubprocVecEnv([make_env() for _ in range(NUM_CPU)])
    env_val = DummyVecEnv([lambda: RealisticTradingEnv(df=val_df, **env_kwargs)])

    os.makedirs("./best_model", exist_ok=True)
    eval_callback = EvalCallback(
        env_val,
        best_model_save_path='./best_model/',
        log_path='./best_model/logs/',
        eval_freq=max(500, 2048 // NUM_CPU),
        deterministic=True,
        render=False
    )

    agent = PPO(
        "MlpPolicy",
        env_train,
        learning_rate=0.00025,
        n_steps=2048,
        batch_size=256,
        device=device,
        verbose=1
    )

    print("\n--- 🚀 [3/3] บอทเริ่มกระโจนเข้าสู่การเรียนรู้แบบคู่ขนาน ---")
    try:
        agent.learn(total_timesteps=300_000, callback=eval_callback)
        agent.save("ppo_realistic_trading_bot_last")
        print("💾 บันทึกโมเดลเสร็จสิ้น! บอทเวอร์ชันที่ดีที่สุดถูกบรรจุอยู่ในโฟลเดอร์ './best_model/'")
    except Exception as e:
        print(f"❌ เกิดข้อผิดพลาดในจังหวะเทรนโมเดล: {e}")

# %%
# ==========================================
# 7. COMPREHENSIVE OUT-OF-SAMPLE TEST
# ==========================================
def test_model():
    TEST_START, TEST_END = '2024-01-01', '2026-07-29'

    print("\n🔮 ดึงข้อมูลตลาดปัจจุบันมาสับไพ่ทดสอบจริง (Out-of-Sample Test)...")
    test_df = fetch_and_prepare_data(TICKERS, TEST_START, TEST_END)

    with open("./exported_data/macro_scaling_stats.json", "r") as f:
        scaling_stats = {k: tuple(v) for k, v in json.load(f).items()}
    test_df = apply_macro_scaling(test_df, scaling_stats)

    os.makedirs("./exported_data", exist_ok=True)
    test_df.to_csv("./exported_data/test_set.csv", index=False)
    print("📁 [Exported] บันทึกไฟล์ Test Set เรียบร้อย -> ./exported_data/test_set.csv")

    model_path = "./best_model/best_model.zip"
    if not os.path.exists(model_path):
        model_path = "ppo_realistic_trading_bot_last"
        print("⚠️ ไม่พบโมเดลคัดสรรพิเศษยามทำลายสถิติ วนกลับไปใช้โมเดลรอบสุดท้าย")

    trained_model = PPO.load(model_path, device=device)

    env_kwargs = get_env_kwargs(len(TICKERS))
    e_test_gym = RealisticTradingEnv(df=test_df, **env_kwargs)
    env_test = DummyVecEnv([lambda: e_test_gym])

    obs = env_test.reset()
    account_memory = []
    num_days = len(test_df.index.unique())

    print("📈 บอทกำลังดำเนินการจำลองการกระจายสินทรัพย์จริงในอดีต...")
    for i in range(num_days):
        action, _ = trained_model.predict(obs, deterministic=True)
        obs, rewards, dones, info = env_test.step(action)

        if i == num_days - 2:
            account_memory = env_test.env_method(method_name="save_asset_memory")[0]

        if dones[0]:
            print("🏁 การทดสอบย้อนหลังสิ้นสุดสมบูรณ์!")
            break

    df_account_value = pd.DataFrame(account_memory)
    df_account_value['date'] = pd.to_datetime(df_account_value['date'])
    df_account_value.set_index('date', inplace=True)

    df_account_value['daily_return'] = df_account_value['account_value'].pct_change()
    df_account_value.dropna(inplace=True)

    explain_bot_performance(df_account_value['daily_return'])

# %%
# ==========================================
# 8. EXECUTION GATEWAY
# ==========================================
if __name__ == "__main__":
    train_model()
    test_model()
# Out:
# ℹ️ Feature ทั้งหมดที่ใช้ (26 ตัว): ['RSI_14', 'RSI_signal', 'RSI_overbought', 'RSI_oversold', 'RSI_above_center', 'MACD_line', 'MACD_signal', 'MACD_histogram', 'MACD_cross', 'EMA_12', 'EMA_26', 'EMA_50', 'EMA_200', 'price_to_EMA50_ratio', 'price_to_EMA200_ratio', 'EMA_golden_cross', 'EMA_death_cross', 'StochRSI_K', 'StochRSI_D', 'StochRSI_cross', 'vix', 'bond_yield', 'gold', 'wti', 'fed_rate', 'm2']
# ℹ️ Multi-timeframe: ปิดอยู่ (ตั้ง USE_MULTI_TIMEFRAME=True เพื่อเปิด)
#
# --- 🛠️ [1/3] เริ่มเตรียมข้อมูลสําหรับฝึกสอนบอท (Training Set) ---
# 📦 กําลังดาวน์โหลดข้อมูลจาก 1999-04-01 ถึง 2019-12-31 (ดึงเผื่อ Buffer ตั้งแต่ 1998-06-15)...
#
# --- 🛠️ [2/3] เริ่มเตรียมข้อมูลสําหรับข้อสอบ (Validation Set) ---
# 📦 กําลังดาวน์โหลดข้อมูลจาก 2020-01-01 ถึง 2023-12-31 (ดึงเผื่อ Buffer ตั้งแต่ 2019-03-17)...
# 📁 [Exported] บันทึกไฟล์ Training/Validation Set และสถิติ Scaling เรียบร้อย
# Using cpu device
#
# --- 🚀 [3/3] บอทเริ่มกระโจนเข้าสู่การเรียนรู้แบบคู่ขนาน ---
# Eval num_timesteps=2048, episode_reward=-0.96 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | -0.959   |
# | time/              |          |
# |    total_timesteps | 2048     |
# ---------------------------------
# New best mean reward!
# day: 1005, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1093389.97
# total_reward: 93389.97
# total_cost: 4621.52
# total_trades: 1005
# Sharpe: 0.565
# =================================
# Eval num_timesteps=4096, episode_reward=-0.96 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | -0.959   |
# | time/              |          |
# |    total_timesteps | 4096     |
# ---------------------------------
# Eval num_timesteps=6144, episode_reward=-0.96 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | -0.959   |
# | time/              |          |
# |    total_timesteps | 6144     |
# ---------------------------------
# day: 1005, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1093389.97
# total_reward: 93389.97
# total_cost: 4621.52
# total_trades: 1005
# Sharpe: 0.565
# =================================
# Eval num_timesteps=8192, episode_reward=-0.96 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | -0.959   |
# | time/              |          |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 186  |
# |    iterations      | 1    |
# |    time_elapsed    | 43   |
# |    total_timesteps | 8192 |
# -----------------------------
# Eval num_timesteps=10240, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.01e+03     |
# |    mean_reward          | 0            |
# | time/                   |              |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0073895715 |
# |    clip_fraction        | 0.0443       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.22        |
# |    explained_variance   | -0.0108      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0194      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00427     |
# |    std                  | 0.978        |
# |    value_loss           | 0.0046       |
# ------------------------------------------
# New best mean reward!
# Eval num_timesteps=12288, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 12288    |
# ---------------------------------
# day: 1005, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=14336, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 14336    |
# ---------------------------------
# Eval num_timesteps=16384, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 16384    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 181   |
# |    iterations      | 2     |
# |    time_elapsed    | 90    |
# |    total_timesteps | 16384 |
# ------------------------------
# day: 1005, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1093389.97
# total_reward: 93389.97
# total_cost: 4621.52
# total_trades: 1005
# Sharpe: 0.565
# =================================
# Eval num_timesteps=18432, episode_reward=-0.96 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.01e+03     |
# |    mean_reward          | -0.959       |
# | time/                   |              |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0037018945 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.18        |
# |    explained_variance   | -1.85        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00685      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00461     |
# |    std                  | 0.973        |
# |    value_loss           | 0.0503       |
# ------------------------------------------
# Eval num_timesteps=20480, episode_reward=-0.96 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | -0.959   |
# | time/              |          |
# |    total_timesteps | 20480    |
# ---------------------------------
# Eval num_timesteps=22528, episode_reward=-0.96 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | -0.959   |
# | time/              |          |
# |    total_timesteps | 22528    |
# ---------------------------------
# day: 1005, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1093389.97
# total_reward: 93389.97
# total_cost: 4621.52
# total_trades: 1005
# Sharpe: 0.565
# =================================
# Eval num_timesteps=24576, episode_reward=-0.96 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | -0.959   |
# | time/              |          |
# |    total_timesteps | 24576    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 183   |
# |    iterations      | 3     |
# |    time_elapsed    | 133   |
# |    total_timesteps | 24576 |
# ------------------------------
# Eval num_timesteps=26624, episode_reward=-0.96 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.01e+03     |
# |    mean_reward          | -0.959       |
# | time/                   |              |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0035422125 |
# |    clip_fraction        | 0.0294       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.16        |
# |    explained_variance   | 0.0316       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0227       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00174     |
# |    std                  | 0.968        |
# |    value_loss           | 0.0625       |
# ------------------------------------------
# day: 1005, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 1093389.97
# total_reward: 93389.97
# total_cost: 4621.52
# total_trades: 1005
# Sharpe: 0.565
# =================================
# Eval num_timesteps=28672, episode_reward=-0.96 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | -0.959   |
# | time/              |          |
# |    total_timesteps | 28672    |
# ---------------------------------
# Eval num_timesteps=30720, episode_reward=-0.96 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | -0.959   |
# | time/              |          |
# |    total_timesteps | 30720    |
# ---------------------------------
# Eval num_timesteps=32768, episode_reward=-0.96 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | -0.959   |
# | time/              |          |
# |    total_timesteps | 32768    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 188   |
# |    iterations      | 4     |
# |    time_elapsed    | 173   |
# |    total_timesteps | 32768 |
# ------------------------------
# day: 1005, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=34816, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.01e+03    |
# |    mean_reward          | 0           |
# | time/                   |             |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.006698682 |
# |    clip_fraction        | 0.0508      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.277       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0133      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00554    |
# |    std                  | 0.964       |
# |    value_loss           | 0.0268      |
# -----------------------------------------
# Eval num_timesteps=36864, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 36864    |
# ---------------------------------
# day: 1005, episode: 110
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=38912, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 38912    |
# ---------------------------------
# Eval num_timesteps=40960, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 40960    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 191   |
# |    iterations      | 5     |
# |    time_elapsed    | 214   |
# |    total_timesteps | 40960 |
# ------------------------------
# Eval num_timesteps=43008, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.01e+03    |
# |    mean_reward          | 0           |
# | time/                   |             |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009834051 |
# |    clip_fraction        | 0.0664      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | 0.475       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0558      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00354    |
# |    std                  | 0.955       |
# |    value_loss           | 0.0761      |
# -----------------------------------------
# day: 1005, episode: 130
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=45056, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 45056    |
# ---------------------------------
# Eval num_timesteps=47104, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 47104    |
# ---------------------------------
# day: 1005, episode: 140
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=49152, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 49152    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 195   |
# |    iterations      | 6     |
# |    time_elapsed    | 251   |
# |    total_timesteps | 49152 |
# ------------------------------
# Eval num_timesteps=51200, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.01e+03    |
# |    mean_reward          | 0           |
# | time/                   |             |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014557235 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.04       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00922    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0161     |
# |    std                  | 0.919       |
# |    value_loss           | 0.00244     |
# -----------------------------------------
# Eval num_timesteps=53248, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 53248    |
# ---------------------------------
# day: 1005, episode: 160
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=55296, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 55296    |
# ---------------------------------
# Eval num_timesteps=57344, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 57344    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 199   |
# |    iterations      | 7     |
# |    time_elapsed    | 288   |
# |    total_timesteps | 57344 |
# ------------------------------
# day: 1005, episode: 170
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=59392, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.01e+03    |
# |    mean_reward          | 0           |
# | time/                   |             |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008752771 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | 0.0131      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.00558     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0071     |
# |    std                  | 0.902       |
# |    value_loss           | 0.0239      |
# -----------------------------------------
# Eval num_timesteps=61440, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 61440    |
# ---------------------------------
# Eval num_timesteps=63488, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 63488    |
# ---------------------------------
# day: 1005, episode: 190
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=65536, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 65536    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 197   |
# |    iterations      | 8     |
# |    time_elapsed    | 331   |
# |    total_timesteps | 65536 |
# ------------------------------
# Eval num_timesteps=67584, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.01e+03    |
# |    mean_reward          | 0           |
# | time/                   |             |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.009330234 |
# |    clip_fraction        | 0.0934      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.93       |
# |    explained_variance   | -0.0384     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.00197     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00416    |
# |    std                  | 0.892       |
# |    value_loss           | 0.0194      |
# -----------------------------------------
# day: 1005, episode: 200
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=69632, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 69632    |
# ---------------------------------
# Eval num_timesteps=71680, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 71680    |
# ---------------------------------
# Eval num_timesteps=73728, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 73728    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 196   |
# |    iterations      | 9     |
# |    time_elapsed    | 375   |
# |    total_timesteps | 73728 |
# ------------------------------
# day: 1005, episode: 220
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=75776, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.01e+03    |
# |    mean_reward          | 0           |
# | time/                   |             |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.009270722 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00754    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 0.863       |
# |    value_loss           | 0.00712     |
# -----------------------------------------
# Eval num_timesteps=77824, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 77824    |
# ---------------------------------
# day: 1005, episode: 230
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=79872, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 79872    |
# ---------------------------------
# Eval num_timesteps=81920, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 81920    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 198   |
# |    iterations      | 10    |
# |    time_elapsed    | 412   |
# |    total_timesteps | 81920 |
# ------------------------------
# Eval num_timesteps=83968, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.01e+03     |
# |    mean_reward          | 0            |
# | time/                   |              |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0072080554 |
# |    clip_fraction        | 0.085        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.79        |
# |    explained_variance   | 0.334        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0453       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00732     |
# |    std                  | 0.853        |
# |    value_loss           | 0.07         |
# ------------------------------------------
# day: 1005, episode: 250
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=86016, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 86016    |
# ---------------------------------
# Eval num_timesteps=88064, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 88064    |
# ---------------------------------
# day: 1005, episode: 260
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=90112, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 90112    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 199   |
# |    iterations      | 11    |
# |    time_elapsed    | 451   |
# |    total_timesteps | 90112 |
# ------------------------------
# Eval num_timesteps=92160, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.01e+03    |
# |    mean_reward          | 0           |
# | time/                   |             |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.015142035 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0213     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0232     |
# |    std                  | 0.819       |
# |    value_loss           | 0.0016      |
# -----------------------------------------
# Eval num_timesteps=94208, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 94208    |
# ---------------------------------
# day: 1005, episode: 280
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=96256, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 96256    |
# ---------------------------------
# Eval num_timesteps=98304, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 98304    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 200   |
# |    iterations      | 12    |
# |    time_elapsed    | 491   |
# |    total_timesteps | 98304 |
# ------------------------------
# day: 1005, episode: 290
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=100352, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.01e+03    |
# |    mean_reward          | 0           |
# | time/                   |             |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.009866361 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0157     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.797       |
# |    value_loss           | 0.0173      |
# -----------------------------------------
# Eval num_timesteps=102400, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 102400   |
# ---------------------------------
# Eval num_timesteps=104448, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 104448   |
# ---------------------------------
# day: 1005, episode: 310
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=106496, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 106496   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 197    |
# |    iterations      | 13     |
# |    time_elapsed    | 538    |
# |    total_timesteps | 106496 |
# -------------------------------
# Eval num_timesteps=108544, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1.01e+03   |
# |    mean_reward          | 0          |
# | time/                   |            |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.01377693 |
# |    clip_fraction        | 0.153      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.49      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0209    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0208    |
# |    std                  | 0.763      |
# |    value_loss           | 0.00118    |
# ----------------------------------------
# day: 1005, episode: 320
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=110592, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 110592   |
# ---------------------------------
# Eval num_timesteps=112640, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 112640   |
# ---------------------------------
# Eval num_timesteps=114688, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 114688   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 191    |
# |    iterations      | 14     |
# |    time_elapsed    | 597    |
# |    total_timesteps | 114688 |
# -------------------------------
# day: 1005, episode: 340
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=116736, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.01e+03    |
# |    mean_reward          | 0           |
# | time/                   |             |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.011457823 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.37       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00935    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0158     |
# |    std                  | 0.733       |
# |    value_loss           | 0.00316     |
# -----------------------------------------
# Eval num_timesteps=118784, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 118784   |
# ---------------------------------
# day: 1005, episode: 350
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=120832, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 120832   |
# ---------------------------------
# Eval num_timesteps=122880, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 122880   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 185    |
# |    iterations      | 15     |
# |    time_elapsed    | 662    |
# |    total_timesteps | 122880 |
# -------------------------------
# Eval num_timesteps=124928, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.01e+03    |
# |    mean_reward          | 0           |
# | time/                   |             |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.007086865 |
# |    clip_fraction        | 0.075       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.000581   |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00529    |
# |    std                  | 0.722       |
# |    value_loss           | 0.00952     |
# -----------------------------------------
# day: 1005, episode: 370
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=126976, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 126976   |
# ---------------------------------
# Eval num_timesteps=129024, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 129024   |
# ---------------------------------
# day: 1005, episode: 380
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=131072, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 131072   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 179    |
# |    iterations      | 16     |
# |    time_elapsed    | 728    |
# |    total_timesteps | 131072 |
# -------------------------------
# Eval num_timesteps=133120, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.01e+03    |
# |    mean_reward          | 0           |
# | time/                   |             |
# |    total_timesteps      | 133120      |
# | train/                  |             |
# |    approx_kl            | 0.011085149 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.22       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0187     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0159     |
# |    std                  | 0.702       |
# |    value_loss           | 0.00131     |
# -----------------------------------------
# Eval num_timesteps=135168, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 135168   |
# ---------------------------------
# day: 1005, episode: 400
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=137216, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 137216   |
# ---------------------------------
# Eval num_timesteps=139264, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 139264   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 176    |
# |    iterations      | 17     |
# |    time_elapsed    | 787    |
# |    total_timesteps | 139264 |
# -------------------------------
# day: 1005, episode: 410
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=141312, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.01e+03    |
# |    mean_reward          | 0           |
# | time/                   |             |
# |    total_timesteps      | 141312      |
# | train/                  |             |
# |    approx_kl            | 0.008442615 |
# |    clip_fraction        | 0.0869      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00184    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00891    |
# |    std                  | 0.686       |
# |    value_loss           | 0.00686     |
# -----------------------------------------
# Eval num_timesteps=143360, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 143360   |
# ---------------------------------
# Eval num_timesteps=145408, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 145408   |
# ---------------------------------
# day: 1005, episode: 430
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=147456, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 147456   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 172    |
# |    iterations      | 18     |
# |    time_elapsed    | 853    |
# |    total_timesteps | 147456 |
# -------------------------------
# Eval num_timesteps=149504, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.01e+03    |
# |    mean_reward          | 0           |
# | time/                   |             |
# |    total_timesteps      | 149504      |
# | train/                  |             |
# |    approx_kl            | 0.012436544 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0277     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 0.656       |
# |    value_loss           | 0.00049     |
# -----------------------------------------
# day: 1005, episode: 440
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=151552, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 151552   |
# ---------------------------------
# Eval num_timesteps=153600, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 153600   |
# ---------------------------------
# Eval num_timesteps=155648, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 155648   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 169    |
# |    iterations      | 19     |
# |    time_elapsed    | 917    |
# |    total_timesteps | 155648 |
# -------------------------------
# day: 1005, episode: 460
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=157696, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1.01e+03   |
# |    mean_reward          | 0          |
# | time/                   |            |
# |    total_timesteps      | 157696     |
# | train/                  |            |
# |    approx_kl            | 0.01089108 |
# |    clip_fraction        | 0.111      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.93      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.00409   |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0102    |
# |    std                  | 0.637      |
# |    value_loss           | 0.0033     |
# ----------------------------------------
# Eval num_timesteps=159744, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 159744   |
# ---------------------------------
# day: 1005, episode: 470
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=161792, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 161792   |
# ---------------------------------
# Eval num_timesteps=163840, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 163840   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 166    |
# |    iterations      | 20     |
# |    time_elapsed    | 984    |
# |    total_timesteps | 163840 |
# -------------------------------
# Eval num_timesteps=165888, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.01e+03    |
# |    mean_reward          | 0           |
# | time/                   |             |
# ...
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=253952, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 253952   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 173    |
# |    iterations      | 31     |
# |    time_elapsed    | 1462   |
# |    total_timesteps | 253952 |
# -------------------------------
# Eval num_timesteps=256000, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.01e+03     |
# |    mean_reward          | 0            |
# | time/                   |              |
# |    total_timesteps      | 256000       |
# | train/                  |              |
# |    approx_kl            | 0.0070058694 |
# |    clip_fraction        | 0.0413       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.05        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.011       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00263     |
# |    std                  | 0.476        |
# |    value_loss           | 9.63e-05     |
# ------------------------------------------
# Eval num_timesteps=258048, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 258048   |
# ---------------------------------
# day: 1005, episode: 760
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=260096, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 260096   |
# ---------------------------------
# Eval num_timesteps=262144, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 262144   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 174    |
# |    iterations      | 32     |
# |    time_elapsed    | 1504   |
# |    total_timesteps | 262144 |
# -------------------------------
# day: 1005, episode: 770
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=264192, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.01e+03     |
# |    mean_reward          | 0            |
# | time/                   |              |
# |    total_timesteps      | 264192       |
# | train/                  |              |
# |    approx_kl            | 0.0044596028 |
# |    clip_fraction        | 0.0482       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.98        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00304     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0038      |
# |    std                  | 0.466        |
# |    value_loss           | 2.43e-05     |
# ------------------------------------------
# Eval num_timesteps=266240, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 266240   |
# ---------------------------------
# Eval num_timesteps=268288, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 268288   |
# ---------------------------------
# day: 1005, episode: 790
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=270336, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 270336   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 174    |
# |    iterations      | 33     |
# |    time_elapsed    | 1547   |
# |    total_timesteps | 270336 |
# -------------------------------
# Eval num_timesteps=272384, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.01e+03     |
# |    mean_reward          | 0            |
# | time/                   |              |
# |    total_timesteps      | 272384       |
# | train/                  |              |
# |    approx_kl            | 0.0059617516 |
# |    clip_fraction        | 0.0546       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00531      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00338     |
# |    std                  | 0.459        |
# |    value_loss           | 9.24e-06     |
# ------------------------------------------
# day: 1005, episode: 800
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=274432, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 274432   |
# ---------------------------------
# Eval num_timesteps=276480, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 276480   |
# ---------------------------------
# Eval num_timesteps=278528, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 278528   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 175    |
# |    iterations      | 34     |
# |    time_elapsed    | 1590   |
# |    total_timesteps | 278528 |
# -------------------------------
# day: 1005, episode: 820
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=280576, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.01e+03    |
# |    mean_reward          | 0           |
# | time/                   |             |
# |    total_timesteps      | 280576      |
# | train/                  |             |
# |    approx_kl            | 0.005903517 |
# |    clip_fraction        | 0.0758      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00493    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00197    |
# |    std                  | 0.451       |
# |    value_loss           | 6.39e-05    |
# -----------------------------------------
# Eval num_timesteps=282624, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 282624   |
# ---------------------------------
# day: 1005, episode: 830
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=284672, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 284672   |
# ---------------------------------
# Eval num_timesteps=286720, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 286720   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 175    |
# |    iterations      | 35     |
# |    time_elapsed    | 1632   |
# |    total_timesteps | 286720 |
# -------------------------------
# Eval num_timesteps=288768, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.01e+03    |
# |    mean_reward          | 0           |
# | time/                   |             |
# |    total_timesteps      | 288768      |
# | train/                  |             |
# |    approx_kl            | 0.004857509 |
# |    clip_fraction        | 0.054       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0124     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00343    |
# |    std                  | 0.446       |
# |    value_loss           | 7.22e-06    |
# -----------------------------------------
# day: 1005, episode: 850
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=290816, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 290816   |
# ---------------------------------
# Eval num_timesteps=292864, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 292864   |
# ---------------------------------
# day: 1005, episode: 860
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=294912, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 294912   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 176    |
# |    iterations      | 36     |
# |    time_elapsed    | 1674   |
# |    total_timesteps | 294912 |
# -------------------------------
# Eval num_timesteps=296960, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.01e+03     |
# |    mean_reward          | 0            |
# | time/                   |              |
# |    total_timesteps      | 296960       |
# | train/                  |              |
# |    approx_kl            | 0.0022493647 |
# |    clip_fraction        | 0.0512       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.81        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0028      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00116     |
# |    std                  | 0.441        |
# |    value_loss           | 1.92e-05     |
# ------------------------------------------
# Eval num_timesteps=299008, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 299008   |
# ---------------------------------
# day: 1005, episode: 880
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=301056, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 301056   |
# ---------------------------------
# Eval num_timesteps=303104, episode_reward=0.00 +/- 0.00
# Episode length: 1006.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.01e+03 |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 303104   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 176    |
# |    iterations      | 37     |
# |    time_elapsed    | 1716   |
# |    total_timesteps | 303104 |
# -------------------------------
# 💾 บันทึกโมเดลเสร็จสิ้น! บอทเวอร์ชันที่ดีที่สุดถูกบรรจุอยู่ในโฟลเดอร์ './best_model/'
#
# 🔮 ดึงข้อมูลตลาดปัจจุบันมาสับไพ่ทดสอบจริง (Out-of-Sample Test)...
# 📦 กําลังดาวน์โหลดข้อมูลจาก 2024-01-01 ถึง 2026-07-29 (ดึงเผื่อ Buffer ตั้งแต่ 2023-03-17)...
# 📁 [Exported] บันทึกไฟล์ Test Set เรียบร้อย -> ./exported_data/test_set.csv
# 📈 บอทกำลังดำเนินการจำลองการกระจายสินทรัพย์จริงในอดีต...
# 🏁 การทดสอบย้อนหลังสิ้นสุดสมบูรณ์!
#
# =======================================================
# 🤖 สรุปผลงานบอทเทรดในหน้าต่างทดสอบจริง (ฉบับเข้าใจง่าย)
# =======================================================
#
# 💰 1. ด้านการทำกำไร (Return)
#    • กำไรสะสมตลอดการทดสอบ: 0.00%
#    • ผลตอบแทนทบต้นเฉลี่ยรายปี (CAGR): 0.00%
#    ❌ สรุป: ล้มเหลว บอททำเงินต้นสูญหาย
#
# 📉 2. ด้านความเสี่ยง (Risk & Drawdown)
#    • ช่วงที่พอร์ตร่วงหนักสุดจากจุดสูงสุด (Max Drawdown): 0.00%
#    ✅ สรุป: ปลอดภัยสูง ระบบคุมสัดส่วนการสูญเสียเงินได้ดีมาก
#
# ⚖️ 3. ความคุ้มค่าและสถิติการชนะ (Efficiency)
#    • ความคุ้มค่าต่อหนึ่งหน่วยความเสี่ยง (Sharpe Ratio): nan
#    ⚠️ สรุป: ความคุ้มค่าน้อยลง ผลตอบแทนอาจไม่สมน้ำสมเนื้อกับความเสี่ยงที่เผชิญ
#    • อัตราความแม่นยำรายวัน (Win Rate): 0.00%
# =======================================================
