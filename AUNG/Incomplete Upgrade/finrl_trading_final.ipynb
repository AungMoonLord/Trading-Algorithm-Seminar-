# %%
import pandas as pd
import yfinance as yf
import ta
import pandas_datareader.data as web
import numpy as np
import torch
import quantstats as qs
import os
import json
import warnings


warnings.filterwarnings('ignore')


from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback

# %%
# ==========================================
# 0. HARDWARE SETUP
# ==========================================
# หมายเหตุ: PPO + MlpPolicy (เครือข่ายเล็ก ไม่ใช่ CNN/Transformer) มี overhead
# การส่งข้อมูลไป-กลับ CPU<->GPU สูงกว่าประโยชน์ที่ได้จากการขนานบน GPU
# นี่คือเหตุผลเชิงเทคนิคที่ยืนยันได้ ไม่ใช่แค่ความเห็น จึงยังคงใช้ CPU
device = "cpu"
print(f"✅ Device Strategy: '{device}' เพราะ PPO+MlpPolicy เป็นโมเดลเล็ก การใช้ GPU จะช้ากว่าเพราะ overhead การส่งข้อมูล")
if torch.cuda.is_available():
    print(f"   - พบ GPU: {torch.cuda.get_device_name(0)} (แต่ไม่แนะนำให้ใช้กับ PPO MlpPolicy)")
else:
    print("   - ไม่พบการ์ดจอแยก ระบบจะทำงานบน CPU (เหมาะสมอยู่แล้วสำหรับโปรเจกต์นี้)")
# Out:
# ✅ Device Strategy: 'cpu' เพราะ PPO+MlpPolicy เป็นโมเดลเล็ก การใช้ GPU จะช้ากว่าเพราะ overhead การส่งข้อมูล
#    - พบ GPU: NVIDIA GeForce RTX 5060 Ti (แต่ไม่แนะนำให้ใช้กับ PPO MlpPolicy)

# %%
# ==========================================
# 1. GLOBAL CONFIGURATION
# ==========================================
TICKERS = ['DIA', 'QQQ', 'SPY']

# แก้ไข #1: เพิ่มค่าธรรมเนียมให้สมจริงขึ้น (รวมค่าคอม + VAT + slippage คร่าวๆ)
TRANSACTION_COST_PCT = 0.015  # 1.5% ต่อการซื้อขายแต่ละครั้ง (ทั้งฝั่งซื้อและขาย)

# แก้ไข #2: publication lag ของข้อมูล macro รายเดือน
FED_FUNDS_LAG_DAYS = 30   # Fed ประกาศเดือนถัดไปหลังจบเดือน
M2_LAG_DAYS = 21          # Fed Reserve เผยแพร่ M2 ล่าช้าประมาณ 3 สัปดาห์

# ⚙️ สวิตช์เปิด/ปิด multi-timeframe indicators (Day/Week/Month)
# เปิดแล้ว state space จะโตขึ้นมาก (เพิ่มอีก ~2 เท่าของ technical indicators)
# แนะนำ: ทดสอบ False ก่อนให้เสถียร แล้วค่อยเปิด True ทีหลังเพื่อวัดผลแยกกัน (ablation study)
USE_MULTI_TIMEFRAME = False

# ---------- รายชื่อ indicator สมบูรณ์ (แทนที่ 4 ตัวเดิมที่มีแค่เส้นเดียว) ----------
COMPLETE_TECHNICAL_INDICATORS = [
    'RSI_14', 'RSI_signal', 'RSI_overbought', 'RSI_oversold', 'RSI_above_center',
    'MACD_line', 'MACD_signal', 'MACD_histogram', 'MACD_cross',
    'EMA_12', 'EMA_26', 'EMA_50', 'EMA_200',
    'price_to_EMA50_ratio', 'price_to_EMA200_ratio',
    'EMA_golden_cross', 'EMA_death_cross',
    'StochRSI_K', 'StochRSI_D', 'StochRSI_cross',
]

# ---------- รายชื่อ multi-timeframe indicator (ใช้เฉพาะเมื่อ USE_MULTI_TIMEFRAME=True) ----------
MULTI_TIMEFRAME_INDICATORS = [
    'RSI_weekly', 'RSI_monthly',
    'MACD_histogram_weekly', 'MACD_histogram_monthly',
]

MACRO_INDICATORS = ['vix', 'bond_yield', 'gold', 'wti', 'fed_rate', 'm2']

TECHNICAL_INDICATORS = COMPLETE_TECHNICAL_INDICATORS + (
    MULTI_TIMEFRAME_INDICATORS if USE_MULTI_TIMEFRAME else []
)
FEATURES = TECHNICAL_INDICATORS + MACRO_INDICATORS

# %%
# ==========================================
# 2. INDICATOR COMPUTATION (สมบูรณ์ + multi-timeframe)
# ==========================================
def compute_complete_indicators(df, price_col='close'):
    """
    คำนวณ indicator ครบชุดต่อหุ้นหนึ่งตัว (ต้อง apply ก่อน merge เป็น panel data)
    แทนที่เวอร์ชันเดิมที่ดึงมาแค่เส้นเดียวต่อ indicator (เช่น MACD ดึงแค่ macd line)
    """
    close = df[price_col]

    # ---------- RSI ชุดสมบูรณ์ ----------
    rsi = ta.momentum.RSIIndicator(close=close, window=14).rsi()
    df['RSI_14'] = rsi
    df['RSI_signal'] = rsi.rolling(window=9).mean()
    df['RSI_overbought'] = (rsi > 70).astype(float)
    df['RSI_oversold'] = (rsi < 30).astype(float)
    df['RSI_above_center'] = (rsi > 50).astype(float)

    # ---------- MACD ชุดสมบูรณ์ ----------
    macd_obj = ta.trend.MACD(close=close, window_slow=26, window_fast=12, window_sign=9)
    macd_line = macd_obj.macd()
    macd_signal = macd_obj.macd_signal()
    df['MACD_line'] = macd_line
    df['MACD_signal'] = macd_signal
    df['MACD_histogram'] = macd_obj.macd_diff()
    prev_diff = (macd_line - macd_signal).shift(1)
    curr_diff = macd_line - macd_signal
    df['MACD_cross'] = np.select(
        [(prev_diff <= 0) & (curr_diff > 0), (prev_diff >= 0) & (curr_diff < 0)],
        [1.0, -1.0], default=0.0
    )

    # ---------- EMA หลายช่วงเวลา + ความสัมพันธ์ ----------
    ema12 = ta.trend.EMAIndicator(close=close, window=12).ema_indicator()
    ema26 = ta.trend.EMAIndicator(close=close, window=26).ema_indicator()
    ema50 = ta.trend.EMAIndicator(close=close, window=50).ema_indicator()
    ema200 = ta.trend.EMAIndicator(close=close, window=200).ema_indicator()
    df['EMA_12'] = ema12
    df['EMA_26'] = ema26
    df['EMA_50'] = ema50
    df['EMA_200'] = ema200
    df['price_to_EMA50_ratio'] = (close - ema50) / ema50
    df['price_to_EMA200_ratio'] = (close - ema200) / ema200
    prev_ema_diff = (ema50 - ema200).shift(1)
    curr_ema_diff = ema50 - ema200
    df['EMA_golden_cross'] = ((prev_ema_diff <= 0) & (curr_ema_diff > 0)).astype(float)
    df['EMA_death_cross'] = ((prev_ema_diff >= 0) & (curr_ema_diff < 0)).astype(float)

    # ---------- Stochastic RSI ชุดสมบูรณ์ ----------
    stochrsi_obj = ta.momentum.StochRSIIndicator(close=close, window=14, smooth1=3, smooth2=3)
    stoch_k = stochrsi_obj.stochrsi_k()
    stoch_d = stochrsi_obj.stochrsi_d()
    df['StochRSI_K'] = stoch_k
    df['StochRSI_D'] = stoch_d
    prev_stoch_diff = (stoch_k - stoch_d).shift(1)
    curr_stoch_diff = stoch_k - stoch_d
    bullish_cross = (prev_stoch_diff <= 0) & (curr_stoch_diff > 0) & (stoch_k < 0.2)
    bearish_cross = (prev_stoch_diff >= 0) & (curr_stoch_diff < 0) & (stoch_k > 0.8)
    df['StochRSI_cross'] = np.select([bullish_cross, bearish_cross], [1.0, -1.0], default=0.0)

    return df


def compute_multi_timeframe_features(df, price_col='close', date_col='date'):
    """
    คำนวณ RSI และ MACD histogram แบบ weekly/monthly โดยไม่เกิด look-ahead bias
    หลักการ: resample เป็นแท่งใหญ่ -> shift(1) เพื่อไม่ให้แท่งปัจจุบัน (ยังไม่ปิด) leak เข้ามา
    -> reindex กลับมาเป็น daily ด้วย ffill (ค่าจะซ้ำกันทั้งสัปดาห์/เดือน ซึ่งถูกต้องแล้ว)
    """
    df = df.copy()
    df[date_col] = pd.to_datetime(df[date_col])
    df = df.set_index(date_col).sort_index()
    close = df[price_col]

    # ---------- Weekly ----------
    weekly_close = close.resample('W-FRI').last()
    weekly_rsi = ta.momentum.RSIIndicator(close=weekly_close, window=14).rsi().shift(1)
    df['RSI_weekly'] = weekly_rsi.reindex(df.index, method='ffill')

    weekly_macd_hist = ta.trend.MACD(close=weekly_close).macd_diff().shift(1)
    df['MACD_histogram_weekly'] = weekly_macd_hist.reindex(df.index, method='ffill')

    # ---------- Monthly ----------
    monthly_close = close.resample('ME').last()
    monthly_rsi = ta.momentum.RSIIndicator(close=monthly_close, window=14).rsi().shift(1)
    df['RSI_monthly'] = monthly_rsi.reindex(df.index, method='ffill')

    monthly_macd_hist = ta.trend.MACD(close=monthly_close).macd_diff().shift(1)
    df['MACD_histogram_monthly'] = monthly_macd_hist.reindex(df.index, method='ffill')

    df = df.reset_index()
    return df

# %%
# ==========================================
# 3. HIGH-PERFORMANCE DATA PIPELINE
# ==========================================
def fetch_and_prepare_data(tickers, start_date, end_date):
    print(f"📦 กําลังดาวน์โหลดข้อมูลจาก {start_date} ถึง {end_date}...")
    processed_dfs = []

    for ticker in tickers:
        try:
            df = yf.download(ticker, start=start_date, end=end_date, progress=False)
            if df.empty:
                continue

            df.columns = [col[0] if isinstance(col, tuple) else col for col in df.columns]
            df = df.reset_index()
            df.rename(columns={'Date': 'date', 'Open': 'open', 'High': 'high', 'Low': 'low',
                                'Close': 'close', 'Volume': 'volume'}, inplace=True)
            df['tic'] = ticker

            # ---- Indicator สมบูรณ์ (แทนที่ 4 บรรทัดเดิมที่ดึงแค่เส้นเดียว) ----
            df = compute_complete_indicators(df, price_col='close')

            # ---- Multi-timeframe (ถ้าเปิดใช้งาน) ----
            if USE_MULTI_TIMEFRAME:
                df = compute_multi_timeframe_features(df, price_col='close', date_col='date')

            processed_dfs.append(df)
        except Exception as e:
            print(f"❌ ไม่สามารถดาวน์โหลด {ticker}: {e}")

    if not processed_dfs:
        raise ValueError("ดาวน์โหลดข้อมูลล้มเหลว กรุณาตรวจสอบการเชื่อมต่ออินเทอร์เน็ต")

    final_df = pd.concat(processed_dfs, ignore_index=True)

    # ---- Macro data จาก yfinance (VIX, Bond Yield, Gold, WTI) ----
    macro_tickers = {"^VIX": "vix", "^TNX": "bond_yield", "GC=F": "gold", "CL=F": "wti"}
    try:
        macro_raw = yf.download(list(macro_tickers.keys()), start=start_date, end=end_date, progress=False)
        macro_df = macro_raw['Close'].copy()
        macro_df.columns = [col[0] if isinstance(col, tuple) else col for col in macro_df.columns]
        macro_df.rename(columns=macro_tickers, inplace=True)
        macro_df = macro_df.reset_index().rename(columns={'Date': 'date'})
        final_df = pd.merge(final_df, macro_df, on='date', how='left')
    except Exception as e:
        print(f"⚠️ ดึงข้อมูล VIX/Bond/Gold/WTI ไม่สำเร็จ: {e} -> จะเติมด้วย NaN แล้ว ffill แทนค่า 0.0")
        for name in macro_tickers.values():
            final_df[name] = np.nan

    # ---- FRED data (Fed Funds Rate, M2) พร้อม publication lag ----
    try:
        fed_funds = web.DataReader('FEDFUNDS', 'fred', start_date, end_date).reset_index()
        m2_supply = web.DataReader('M2SL', 'fred', start_date, end_date).reset_index()

        fed_funds.rename(columns={'DATE': 'date', 'FEDFUNDS': 'fed_rate'}, inplace=True)
        m2_supply.rename(columns={'DATE': 'date', 'M2SL': 'm2'}, inplace=True)

        # แก้ไข #2 (สำคัญที่สุด): เลื่อนวันที่ข้อมูลจะ "ถูกมองเห็น" ให้ตรงกับวันที่ประกาศจริง
        fed_funds['date'] = fed_funds['date'] + pd.Timedelta(days=FED_FUNDS_LAG_DAYS)
        m2_supply['date'] = m2_supply['date'] + pd.Timedelta(days=M2_LAG_DAYS)

        macro_fred = pd.merge(fed_funds, m2_supply, on='date', how='outer')
        final_df = pd.merge(final_df, macro_fred, on='date', how='left')
    except Exception as e:
        print(f"⚠️ ดึงข้อมูล FRED ไม่สำเร็จ: {e} -> จะเติมด้วย NaN แล้ว ffill แทนค่า 0.0")
        final_df['fed_rate'] = np.nan
        final_df['m2'] = np.nan

    # ---- จัดเรียงและเติมข้อมูล ----
    final_df.sort_values(['date', 'tic'], inplace=True)

    # แก้ไข #4: เอา bfill() ออก เพราะมันเอาค่าจากอนาคตมาเติมอดีต (look-ahead bias)
    final_df = final_df.groupby('tic', group_keys=False).apply(lambda g: g.ffill())

    # ⚠️ multi-timeframe columns (weekly/monthly) ใช้เวลา warm-up นานกว่า indicator รายวันมาก
    # (MACD monthly ต้องการ ~35 เดือนของข้อมูลก่อนจะไม่เป็น NaN) ถ้า dropna() รวมทุกคอลัมน์
    # พร้อมกันแบบเดิม อาจทำให้ข้อมูลทั้งหมดหายไปหมดถ้าช่วงข้อมูลไม่ยาวพอ
    # จึงเติม 0.0 ให้ multi-timeframe columns ที่ยัง NaN อยู่หลัง ffill แทนการ drop ทั้งแถว
    # (0.0 สมเหตุสมผลกว่าตรงนี้ เพราะ MACD histogram ที่ไม่มีข้อมูลพอ = "ยังไม่มีสัญญาณ" ซึ่งใกล้เคียง 0)
    if USE_MULTI_TIMEFRAME:
        for col in MULTI_TIMEFRAME_INDICATORS:
            if col in final_df.columns:
                still_nan = final_df[col].isna().sum()
                nan_ratio = still_nan / len(final_df) if len(final_df) > 0 else 0
                if still_nan > 0:
                    print(f"ℹ️ '{col}' มี NaN เหลือ {still_nan} แถว ({nan_ratio:.0%}) ช่วง warm-up -> เติมด้วย 0.0")
                if nan_ratio > 0.3:
                    print(f"⚠️ คำเตือน: '{col}' เป็น NaN ถึง {nan_ratio:.0%} ของข้อมูลทั้งหมด "
                          f"แปลว่าช่วงเวลา {start_date} ถึง {end_date} อาจสั้นเกินไปสำหรับ indicator "
                          f"รายเดือน/รายสัปดาห์นี้ (MACD monthly ต้องการข้อมูลจริงอย่างน้อย ~3 ปี) "
                          f"ค่า 0.0 ที่เติมเข้าไปจำนวนมากจะทำให้ feature นี้แทบไม่มีประโยชน์เชิงสัญญาณ")
                final_df[col] = final_df[col].fillna(0.0)

    rows_before = len(final_df)
    final_df.dropna(inplace=True)
    rows_after = len(final_df)
    if rows_before != rows_after:
        print(f"ℹ️ ตัดแถวที่มี NaN (ช่วง warm-up ของ indicator/publication lag) ออก {rows_before - rows_after} แถว")
    if rows_after == 0:
        raise ValueError(
            "⚠️ ข้อมูลเหลือ 0 แถวหลัง dropna! สาเหตุที่เป็นไปได้: ช่วงเวลา start_date-end_date "
            "สั้นเกินไปสำหรับ indicator ที่ต้องการ warm-up ยาว (เช่น EMA_200 ต้องการ ~200 วันทำการ). "
            "ลองขยายช่วงเวลาหรือลด window ของ indicator ที่ใช้"
        )

    date_list = sorted(final_df['date'].unique())
    date2day = {date: day for day, date in enumerate(date_list)}
    final_df['day'] = final_df['date'].map(date2day)
    final_df['date'] = final_df['date'].dt.strftime('%Y-%m-%d')

    final_df = final_df.sort_values(['date', 'tic'])
    final_df.index = final_df['day'].values
    return final_df


def compute_macro_scaling_stats(train_df):
    """
    Macro features (m2, fed_rate) มีสเกลใหญ่กว่า technical indicators มาก
    คำนวณ mean/std จาก TRAIN SET เท่านั้น (ป้องกัน leakage) เพื่อนำไปใช้ normalize
    ทั้ง train/val/test ด้วยค่าเดียวกัน
    """
    scale_cols = ['m2', 'fed_rate', 'vix', 'bond_yield', 'gold', 'wti']
    stats = {}
    for col in scale_cols:
        if col in train_df.columns:
            mean = train_df[col].mean()
            std = train_df[col].std()
            std = std if std > 1e-8 else 1.0
            stats[col] = (mean, std)
    return stats


def apply_macro_scaling(df, stats):
    """นำสถิติที่คำนวณจาก train set มาใช้ normalize คอลัมน์ macro ของ df ใดๆ"""
    df = df.copy()
    for col, (mean, std) in stats.items():
        if col in df.columns:
            df[col] = (df[col] - mean) / std
    return df

# %%
# ==========================================
# 4. ROBUST CUSTOM ENVIRONMENT
# ==========================================
class RealisticTradingEnv(StockTradingEnv):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.vix_array = self.df['vix'].values if 'vix' in self.df.columns else np.zeros(len(self.df))

    def _calculate_reward(self):
        current_portfolio_value = self.state[0] + sum(
            np.array(self.state[1:(self.stock_dim + 1)]) *
            np.array(self.state[(self.stock_dim + 1):(self.stock_dim * 2 + 1)])
        )

        previous_portfolio_value = self.asset_memory[-1] if len(self.asset_memory) > 0 else self.initial_amount
        if previous_portfolio_value <= 0:
            previous_portfolio_value = self.initial_amount

        step_return = (current_portfolio_value - previous_portfolio_value) / previous_portfolio_value
        transaction_costs = self.cost * self.reward_scaling

        # Asymmetric Reward: ลงโทษการขาดทุน 2 เท่า
        if step_return < 0:
            step_return *= 2.0

        current_vix = self.vix_array[self.day] if self.day < len(self.vix_array) else 0.0
        invested_ratio = 1 - (self.state[0] / current_portfolio_value) if current_portfolio_value > 0 else 0

        # current_vix ถูก normalize แล้ว (z-score) ไม่ใช่ค่าดิบ 0-80 อีกต่อไป
        # threshold ปรับจาก "vix > 20" เป็น "z-score > 0" (สูงกว่าค่าเฉลี่ยในอดีต)
        risk_penalty = 0.0
        if current_vix > 0.0:
            vix_excess = current_vix / 10.0
            risk_penalty = vix_excess * invested_ratio * (abs(step_return) + 0.001)

        raw_reward = (step_return * 100) - transaction_costs - (risk_penalty * 100)
        # ใช้ tanh แทน hard clip: บีบค่า extreme แบบนุ่มนวล แทนตัดทิ้งตรงๆ
        reward = 10.0 * np.tanh(raw_reward / 10.0)

        return float(reward)


def get_env_kwargs(stock_dimension):
    state_space = 1 + (2 * stock_dimension) + (len(FEATURES) * stock_dimension)
    return {
        "hmax": 100,
        "initial_amount": 1000000,
        "num_stock_shares": [0] * stock_dimension,
        "state_space": state_space,
        "stock_dim": stock_dimension,
        "tech_indicator_list": FEATURES,
        "action_space": stock_dimension,
        "reward_scaling": 1e-4,
        "buy_cost_pct": [TRANSACTION_COST_PCT] * stock_dimension,
        "sell_cost_pct": [TRANSACTION_COST_PCT] * stock_dimension,
    }

# %%
# ==========================================
# 5. TRANSLATION & REPORT ENGINE
# ==========================================
def explain_bot_performance(returns):
    print("\n" + "=" * 55)
    print("🤖 สรุปผลงานบอทเทรดในหน้าต่างทดสอบจริง (ฉบับเข้าใจง่าย)")
    print("=" * 55)

    total_return = qs.stats.comp(returns) * 100
    cagr = qs.stats.cagr(returns) * 100
    max_dd = qs.stats.max_drawdown(returns) * 100
    sharpe = qs.stats.sharpe(returns)
    win_rate = qs.stats.win_rate(returns) * 100

    print("\n💰 1. ด้านการทำกำไร (Return)")
    print(f"   • กำไรสะสมตลอดการทดสอบ: {total_return:.2f}%")
    print(f"   • ผลตอบแทนทบต้นเฉลี่ยรายปี (CAGR): {cagr:.2f}%")
    if cagr > 12:
        print("   ✅ สรุป: ยอดเยี่ยม! บอทสร้างผลงานชนะอัตราเฉลี่ยของตลาดส่วนใหญ่")
    elif cagr > 0:
        print("   ⚠️ สรุป: พอใช้ได้ พอร์ตโตขึ้นแต่ยังไม่โดดเด่นนัก")
    else:
        print("   ❌ สรุป: ล้มเหลว บอททำเงินต้นสูญหาย")

    print("\n📉 2. ด้านความเสี่ยง (Risk & Drawdown)")
    print(f"   • ช่วงที่พอร์ตร่วงหนักสุดจากจุดสูงสุด (Max Drawdown): {max_dd:.2f}%")
    if max_dd > -15:
        print("   ✅ สรุป: ปลอดภัยสูง ระบบคุมสัดส่วนการสูญเสียเงินได้ดีมาก")
    elif max_dd > -30:
        print("   ⚠️ สรุป: ปานกลาง พอร์ตแกว่งตามมาตรฐานสไตล์กองทุนเชิงรุก")
    else:
        print("   ❌ สรุป: อันตรายมาก! บอทปล่อยให้พอร์ตเสียหายหนักเกินไป")

    print("\n⚖️ 3. ความคุ้มค่าและสถิติการชนะ (Efficiency)")
    print(f"   • ความคุ้มค่าต่อหนึ่งหน่วยความเสี่ยง (Sharpe Ratio): {sharpe:.2f}")
    if sharpe >= 1.0:
        print("   ✅ สรุป: ดีเยี่ยม กำไรที่ได้คุ้มค่าอย่างมากกับความเสี่ยงที่ถือครอง")
    else:
        print("   ⚠️ สรุป: ความคุ้มค่าน้อยลง ผลตอบแทนอาจไม่สมน้ำสมเนื้อกับความเสี่ยงที่เผชิญ")
    print(f"   • อัตราความแม่นยำรายวัน (Win Rate): {win_rate:.2f}%")
    print("=" * 55 + "\n")

# %%
# ==========================================
# 6. HIGH-SPEED TRAINING PIPELINE WITH VALIDATION
# ==========================================
def train_model():
    TRAIN_START, TRAIN_END = '1999-04-01', '2019-12-31'
    VAL_START, VAL_END = '2020-01-01', '2023-12-31'

    os.makedirs("./exported_data", exist_ok=True)

    print(f"\nℹ️ Feature ทั้งหมดที่ใช้ ({len(FEATURES)} ตัว): {FEATURES}")
    print(f"ℹ️ Multi-timeframe: {'เปิดใช้งาน' if USE_MULTI_TIMEFRAME else 'ปิดอยู่ (ตั้ง USE_MULTI_TIMEFRAME=True เพื่อเปิด)'}")

    print("\n--- 🛠️ [1/3] เริ่มเตรียมข้อมูลสําหรับฝึกสอนบอท (Training Set) ---")
    train_df = fetch_and_prepare_data(TICKERS, TRAIN_START, TRAIN_END)

    print("\n--- 🛠️ [2/3] เริ่มเตรียมข้อมูลสําหรับข้อสอบ (Validation Set) ---")
    val_df = fetch_and_prepare_data(TICKERS, VAL_START, VAL_END)

    # คำนวณสถิติ scaling จาก TRAIN SET เท่านั้น (ป้องกัน leakage)
    scaling_stats = compute_macro_scaling_stats(train_df)
    train_df = apply_macro_scaling(train_df, scaling_stats)
    val_df = apply_macro_scaling(val_df, scaling_stats)

    with open("./exported_data/macro_scaling_stats.json", "w") as f:
        json.dump({k: list(v) for k, v in scaling_stats.items()}, f)

    train_df.to_csv("./exported_data/train_set.csv", index=False)
    val_df.to_csv("./exported_data/validation_set.csv", index=False)
    print("📁 [Exported] บันทึกไฟล์ Training/Validation Set และสถิติ Scaling เรียบร้อย")

    env_kwargs = get_env_kwargs(len(TICKERS))

    def make_env():
        return lambda: RealisticTradingEnv(df=train_df, **env_kwargs)

    NUM_CPU = 4
    env_train = SubprocVecEnv([make_env() for _ in range(NUM_CPU)])
    env_val = DummyVecEnv([lambda: RealisticTradingEnv(df=val_df, **env_kwargs)])

    os.makedirs("./best_model", exist_ok=True)
    eval_callback = EvalCallback(
        env_val,
        best_model_save_path='./best_model/',
        log_path='./best_model/logs/',
        eval_freq=max(500, 2048 // NUM_CPU),
        deterministic=True,
        render=False
    )

    agent = PPO(
        "MlpPolicy",
        env_train,
        learning_rate=0.00025,
        n_steps=2048,
        batch_size=256,
        device=device,
        verbose=1
    )

    print("\n--- 🚀 [3/3] บอทเริ่มกระโจนเข้าสู่การเรียนรู้แบบคู่ขนาน ---")
    try:
        # เพิ่ม timesteps จาก 15,000 -> 300,000 (train set ~5,000 วัน/episode
        # 300,000 steps ≈ 60 episodes ซึ่งเพียงพอให้ PPO ปรับ policy โดยไม่ overfit เกินจำเป็น)
        agent.learn(total_timesteps=300_000, callback=eval_callback)
        agent.save("ppo_realistic_trading_bot_last")
        print("💾 บันทึกโมเดลเสร็จสิ้น! บอทเวอร์ชันที่ดีที่สุดถูกบรรจุอยู่ในโฟลเดอร์ './best_model/'")
    except Exception as e:
        print(f"❌ เกิดข้อผิดพลาดในจังหวะเทรนโมเดล: {e}")

# %%
# ==========================================
# 7. COMPREHENSIVE OUT-OF-SAMPLE TEST
# ==========================================
def test_model():
    TEST_START, TEST_END = '2024-01-01', '2026-07-29'

    print("\n🔮 ดึงข้อมูลตลาดปัจจุบันมาสับไพ่ทดสอบจริง (Out-of-Sample Test)...")
    test_df = fetch_and_prepare_data(TICKERS, TEST_START, TEST_END)

    # โหลดสถิติ scaling ที่บันทึกไว้ตอน train_model() เพื่อ normalize ด้วยค่าเดียวกันเสมอ
    with open("./exported_data/macro_scaling_stats.json", "r") as f:
        scaling_stats = {k: tuple(v) for k, v in json.load(f).items()}
    test_df = apply_macro_scaling(test_df, scaling_stats)

    os.makedirs("./exported_data", exist_ok=True)
    test_df.to_csv("./exported_data/test_set.csv", index=False)
    print("📁 [Exported] บันทึกไฟล์ Test Set เรียบร้อย -> ./exported_data/test_set.csv")

    model_path = "./best_model/best_model.zip"
    if not os.path.exists(model_path):
        model_path = "ppo_realistic_trading_bot_last"
        print("⚠️ ไม่พบโมเดลคัดสรรพิเศษยามทำลายสถิติ วนกลับไปใช้โมเดลรอบสุดท้าย")

    trained_model = PPO.load(model_path, device=device)

    env_kwargs = get_env_kwargs(len(TICKERS))
    e_test_gym = RealisticTradingEnv(df=test_df, **env_kwargs)
    env_test = DummyVecEnv([lambda: e_test_gym])

    obs = env_test.reset()
    account_memory = []
    num_days = len(test_df.index.unique())

    print("📈 บอทกำลังดำเนินการจำลองการกระจายสินทรัพย์จริงในอดีต...")
    for i in range(num_days):
        action, _ = trained_model.predict(obs, deterministic=True)
        obs, rewards, dones, info = env_test.step(action)

        if i == num_days - 2:
            account_memory = env_test.env_method(method_name="save_asset_memory")[0]

        if dones[0]:
            print("🏁 การทดสอบย้อนหลังสิ้นสุดสมบูรณ์!")
            break

    df_account_value = pd.DataFrame(account_memory)
    df_account_value['date'] = pd.to_datetime(df_account_value['date'])
    df_account_value.set_index('date', inplace=True)

    df_account_value['daily_return'] = df_account_value['account_value'].pct_change()
    df_account_value.dropna(inplace=True)

    explain_bot_performance(df_account_value['daily_return'])

# %%
# ==========================================
# 8. EXECUTION GATEWAY
# ==========================================
if __name__ == "__main__":
    train_model()
    test_model()
# Out:
# ℹ️ Feature ทั้งหมดที่ใช้ (26 ตัว): ['RSI_14', 'RSI_signal', 'RSI_overbought', 'RSI_oversold', 'RSI_above_center', 'MACD_line', 'MACD_signal', 'MACD_histogram', 'MACD_cross', 'EMA_12', 'EMA_26', 'EMA_50', 'EMA_200', 'price_to_EMA50_ratio', 'price_to_EMA200_ratio', 'EMA_golden_cross', 'EMA_death_cross', 'StochRSI_K', 'StochRSI_D', 'StochRSI_cross', 'vix', 'bond_yield', 'gold', 'wti', 'fed_rate', 'm2']
# ℹ️ Multi-timeframe: ปิดอยู่ (ตั้ง USE_MULTI_TIMEFRAME=True เพื่อเปิด)
#
# --- 🛠️ [1/3] เริ่มเตรียมข้อมูลสําหรับฝึกสอนบอท (Training Set) ---
# 📦 กําลังดาวน์โหลดข้อมูลจาก 1999-04-01 ถึง 2019-12-31...
# ℹ️ ตัดแถวที่มี NaN (ช่วง warm-up ของ indicator/publication lag) ออก 1074 แถว
#
# --- 🛠️ [2/3] เริ่มเตรียมข้อมูลสําหรับข้อสอบ (Validation Set) ---
# 📦 กําลังดาวน์โหลดข้อมูลจาก 2020-01-01 ถึง 2023-12-31...
# ℹ️ ตัดแถวที่มี NaN (ช่วง warm-up ของ indicator/publication lag) ออก 597 แถว
# 📁 [Exported] บันทึกไฟล์ Training/Validation Set และสถิติ Scaling เรียบร้อย
# Using cpu device
#
# --- 🚀 [3/3] บอทเริ่มกระโจนเข้าสู่การเรียนรู้แบบคู่ขนาน ---
# Eval num_timesteps=2048, episode_reward=0.00 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 2048     |
# ---------------------------------
# New best mean reward!
# day: 806, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=4096, episode_reward=0.00 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 4096     |
# ---------------------------------
# Eval num_timesteps=6144, episode_reward=0.00 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 6144     |
# ---------------------------------
# day: 806, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1000000.00
# total_reward: 0.00
# total_cost: 0.00
# total_trades: 0
# =================================
# Eval num_timesteps=8192, episode_reward=0.00 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 0        |
# | time/              |          |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 255  |
# |    iterations      | 1    |
# |    time_elapsed    | 32   |
# |    total_timesteps | 8192 |
# -----------------------------
# Eval num_timesteps=10240, episode_reward=17.41 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 807          |
# |    mean_reward          | 17.4         |
# | time/                   |              |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0034365407 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.0093      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.843        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00275     |
# |    std                  | 1            |
# |    value_loss           | 1.91         |
# ------------------------------------------
# New best mean reward!
# Eval num_timesteps=12288, episode_reward=17.41 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 17.4     |
# | time/              |          |
# |    total_timesteps | 12288    |
# ---------------------------------
# day: 806, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1178329.66
# total_reward: 178329.66
# total_cost: 11804.42
# total_trades: 806
# Sharpe: 0.567
# =================================
# Eval num_timesteps=14336, episode_reward=17.41 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 17.4     |
# | time/              |          |
# |    total_timesteps | 14336    |
# ---------------------------------
# Eval num_timesteps=16384, episode_reward=17.41 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 17.4     |
# | time/              |          |
# |    total_timesteps | 16384    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 258   |
# |    iterations      | 2     |
# |    time_elapsed    | 63    |
# |    total_timesteps | 16384 |
# ------------------------------
# day: 806, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1178329.66
# total_reward: 178329.66
# total_cost: 11804.42
# total_trades: 806
# Sharpe: 0.567
# =================================
# Eval num_timesteps=18432, episode_reward=17.41 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 807          |
# |    mean_reward          | 17.4         |
# | time/                   |              |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0014201312 |
# |    clip_fraction        | 0.00212      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.0045       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.63         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0011      |
# |    std                  | 1            |
# |    value_loss           | 2.9          |
# ------------------------------------------
# Eval num_timesteps=20480, episode_reward=17.41 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 17.4     |
# | time/              |          |
# |    total_timesteps | 20480    |
# ---------------------------------
# Eval num_timesteps=22528, episode_reward=17.41 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 17.4     |
# | time/              |          |
# |    total_timesteps | 22528    |
# ---------------------------------
# day: 806, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1178329.66
# total_reward: 178329.66
# total_cost: 11804.42
# total_trades: 806
# Sharpe: 0.567
# =================================
# Eval num_timesteps=24576, episode_reward=17.41 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 17.4     |
# | time/              |          |
# |    total_timesteps | 24576    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 257   |
# |    iterations      | 3     |
# |    time_elapsed    | 95    |
# |    total_timesteps | 24576 |
# ------------------------------
# Eval num_timesteps=26624, episode_reward=17.67 +/- 0.00
# Episode length: 807.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 807         |
# |    mean_reward          | 17.7        |
# | time/                   |             |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.004811545 |
# |    clip_fraction        | 0.0297      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | -0.0587     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.15        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00261    |
# |    std                  | 1           |
# |    value_loss           | 1.92        |
# -----------------------------------------
# New best mean reward!
# day: 806, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 1180197.18
# total_reward: 180197.18
# total_cost: 14775.88
# total_trades: 1099
# Sharpe: 0.495
# =================================
# Eval num_timesteps=28672, episode_reward=17.67 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 17.7     |
# | time/              |          |
# |    total_timesteps | 28672    |
# ---------------------------------
# Eval num_timesteps=30720, episode_reward=17.67 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 17.7     |
# | time/              |          |
# |    total_timesteps | 30720    |
# ---------------------------------
# Eval num_timesteps=32768, episode_reward=17.67 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 17.7     |
# | time/              |          |
# |    total_timesteps | 32768    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 258   |
# |    iterations      | 4     |
# |    time_elapsed    | 126   |
# |    total_timesteps | 32768 |
# ------------------------------
# day: 806, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 1189623.59
# total_reward: 189623.59
# total_cost: 14777.80
# total_trades: 1860
# Sharpe: 0.418
# =================================
# Eval num_timesteps=34816, episode_reward=18.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 807          |
# |    mean_reward          | 18.6         |
# | time/                   |              |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0034044227 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.00207      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.25         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0024      |
# |    std                  | 0.998        |
# |    value_loss           | 4.39         |
# ------------------------------------------
# New best mean reward!
# Eval num_timesteps=36864, episode_reward=18.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 18.6     |
# | time/              |          |
# |    total_timesteps | 36864    |
# ---------------------------------
# day: 806, episode: 110
# begin_total_asset: 1000000.00
# end_total_asset: 1189623.59
# total_reward: 189623.59
# total_cost: 14777.80
# total_trades: 1860
# Sharpe: 0.418
# =================================
# Eval num_timesteps=38912, episode_reward=18.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 18.6     |
# | time/              |          |
# |    total_timesteps | 38912    |
# ---------------------------------
# Eval num_timesteps=40960, episode_reward=18.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 18.6     |
# | time/              |          |
# |    total_timesteps | 40960    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 258   |
# |    iterations      | 5     |
# |    time_elapsed    | 158   |
# |    total_timesteps | 40960 |
# ------------------------------
# Eval num_timesteps=43008, episode_reward=25.43 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 807          |
# |    mean_reward          | 25.4         |
# | time/                   |              |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0021838648 |
# |    clip_fraction        | 0.00311      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.0859       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.2          |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00141     |
# |    std                  | 0.998        |
# |    value_loss           | 6.78         |
# ------------------------------------------
# New best mean reward!
# day: 806, episode: 130
# begin_total_asset: 1000000.00
# end_total_asset: 1257721.23
# total_reward: 257721.23
# total_cost: 14777.18
# total_trades: 2418
# Sharpe: 0.519
# =================================
# Eval num_timesteps=45056, episode_reward=25.43 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 25.4     |
# | time/              |          |
# |    total_timesteps | 45056    |
# ---------------------------------
# Eval num_timesteps=47104, episode_reward=25.43 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 25.4     |
# | time/              |          |
# |    total_timesteps | 47104    |
# ---------------------------------
# day: 806, episode: 140
# begin_total_asset: 1000000.00
# end_total_asset: 1257721.23
# total_reward: 257721.23
# total_cost: 14777.18
# total_trades: 2418
# Sharpe: 0.519
# =================================
# Eval num_timesteps=49152, episode_reward=25.43 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 25.4     |
# | time/              |          |
# |    total_timesteps | 49152    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 258   |
# |    iterations      | 6     |
# |    time_elapsed    | 190   |
# |    total_timesteps | 49152 |
# ------------------------------
# Eval num_timesteps=51200, episode_reward=28.33 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 807          |
# |    mean_reward          | 28.3         |
# | time/                   |              |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0054266853 |
# |    clip_fraction        | 0.042        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.0241       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.86         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00402     |
# |    std                  | 1            |
# |    value_loss           | 5.6          |
# ------------------------------------------
# New best mean reward!
# Eval num_timesteps=53248, episode_reward=28.33 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 28.3     |
# | time/              |          |
# |    total_timesteps | 53248    |
# ---------------------------------
# day: 806, episode: 160
# begin_total_asset: 1000000.00
# end_total_asset: 1287512.47
# total_reward: 287512.47
# total_cost: 14778.32
# total_trades: 2266
# Sharpe: 0.536
# =================================
# Eval num_timesteps=55296, episode_reward=28.33 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 28.3     |
# | time/              |          |
# |    total_timesteps | 55296    |
# ---------------------------------
# Eval num_timesteps=57344, episode_reward=28.33 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 28.3     |
# | time/              |          |
# |    total_timesteps | 57344    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 258   |
# |    iterations      | 7     |
# |    time_elapsed    | 221   |
# |    total_timesteps | 57344 |
# ------------------------------
# day: 806, episode: 170
# begin_total_asset: 1000000.00
# end_total_asset: 1322939.02
# total_reward: 322939.02
# total_cost: 14775.74
# total_trades: 2278
# Sharpe: 0.558
# =================================
# Eval num_timesteps=59392, episode_reward=31.83 +/- 0.00
# Episode length: 807.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 807         |
# |    mean_reward          | 31.8        |
# | time/                   |             |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.003976351 |
# |    clip_fraction        | 0.0193      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.0527      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.94        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00242    |
# |    std                  | 0.997       |
# |    value_loss           | 10.7        |
# -----------------------------------------
# New best mean reward!
# Eval num_timesteps=61440, episode_reward=31.83 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 31.8     |
# | time/              |          |
# |    total_timesteps | 61440    |
# ---------------------------------
# Eval num_timesteps=63488, episode_reward=31.83 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 31.8     |
# | time/              |          |
# |    total_timesteps | 63488    |
# ---------------------------------
# day: 806, episode: 190
# begin_total_asset: 1000000.00
# end_total_asset: 1322939.02
# total_reward: 322939.02
# total_cost: 14775.74
# total_trades: 2278
# Sharpe: 0.558
# =================================
# Eval num_timesteps=65536, episode_reward=31.83 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 31.8     |
# | time/              |          |
# |    total_timesteps | 65536    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 259   |
# |    iterations      | 8     |
# |    time_elapsed    | 253   |
# |    total_timesteps | 65536 |
# ------------------------------
# Eval num_timesteps=67584, episode_reward=28.31 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 807          |
# |    mean_reward          | 28.3         |
# | time/                   |              |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0046680234 |
# |    clip_fraction        | 0.0316       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | 0.199        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.13         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00296     |
# |    std                  | 0.995        |
# |    value_loss           | 5.44         |
# ------------------------------------------
# day: 806, episode: 200
# begin_total_asset: 1000000.00
# end_total_asset: 1287303.01
# total_reward: 287303.01
# total_cost: 14776.29
# total_trades: 2265
# Sharpe: 0.536
# =================================
# Eval num_timesteps=69632, episode_reward=28.31 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 28.3     |
# | time/              |          |
# |    total_timesteps | 69632    |
# ---------------------------------
# Eval num_timesteps=71680, episode_reward=28.31 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 28.3     |
# | time/              |          |
# |    total_timesteps | 71680    |
# ---------------------------------
# Eval num_timesteps=73728, episode_reward=28.31 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 28.3     |
# | time/              |          |
# |    total_timesteps | 73728    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 259   |
# |    iterations      | 9     |
# |    time_elapsed    | 284   |
# |    total_timesteps | 73728 |
# ------------------------------
# day: 806, episode: 220
# begin_total_asset: 1000000.00
# end_total_asset: 1308073.27
# total_reward: 308073.27
# total_cost: 14777.87
# total_trades: 2290
# Sharpe: 0.562
# =================================
# Eval num_timesteps=75776, episode_reward=30.38 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 807          |
# |    mean_reward          | 30.4         |
# | time/                   |              |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0033025646 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | 0.0556       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.2          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00146     |
# |    std                  | 0.995        |
# |    value_loss           | 13           |
# ------------------------------------------
# Eval num_timesteps=77824, episode_reward=30.38 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 30.4     |
# | time/              |          |
# |    total_timesteps | 77824    |
# ---------------------------------
# day: 806, episode: 230
# begin_total_asset: 1000000.00
# end_total_asset: 1308073.27
# total_reward: 308073.27
# total_cost: 14777.87
# total_trades: 2290
# Sharpe: 0.562
# =================================
# Eval num_timesteps=79872, episode_reward=30.38 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 30.4     |
# | time/              |          |
# |    total_timesteps | 79872    |
# ---------------------------------
# Eval num_timesteps=81920, episode_reward=30.38 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 30.4     |
# | time/              |          |
# |    total_timesteps | 81920    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 258   |
# |    iterations      | 10    |
# |    time_elapsed    | 316   |
# |    total_timesteps | 81920 |
# ------------------------------
# Eval num_timesteps=83968, episode_reward=26.53 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 807          |
# |    mean_reward          | 26.5         |
# | time/                   |              |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0031340276 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.23        |
# |    explained_variance   | 0.288        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 12.6         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0017      |
# |    std                  | 0.99         |
# |    value_loss           | 21.2         |
# ------------------------------------------
# day: 806, episode: 250
# begin_total_asset: 1000000.00
# end_total_asset: 1269208.18
# total_reward: 269208.18
# total_cost: 16000.51
# total_trades: 1839
# Sharpe: 0.524
# =================================
# Eval num_timesteps=86016, episode_reward=26.53 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 26.5     |
# | time/              |          |
# |    total_timesteps | 86016    |
# ---------------------------------
# Eval num_timesteps=88064, episode_reward=26.53 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 26.5     |
# | time/              |          |
# |    total_timesteps | 88064    |
# ---------------------------------
# day: 806, episode: 260
# begin_total_asset: 1000000.00
# end_total_asset: 1269208.18
# total_reward: 269208.18
# total_cost: 16000.51
# total_trades: 1839
# Sharpe: 0.524
# =================================
# Eval num_timesteps=90112, episode_reward=26.53 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 26.5     |
# | time/              |          |
# |    total_timesteps | 90112    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 258   |
# |    iterations      | 11    |
# |    time_elapsed    | 348   |
# |    total_timesteps | 90112 |
# ------------------------------
# Eval num_timesteps=92160, episode_reward=25.41 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 807        |
# |    mean_reward          | 25.4       |
# | time/                   |            |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.00439444 |
# |    clip_fraction        | 0.0218     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.22      |
# |    explained_variance   | 0.0789     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 5.81       |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.00201   |
# |    std                  | 0.987      |
# |    value_loss           | 11.7       |
# ----------------------------------------
# Eval num_timesteps=94208, episode_reward=25.41 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 25.4     |
# | time/              |          |
# |    total_timesteps | 94208    |
# ---------------------------------
# day: 806, episode: 280
# begin_total_asset: 1000000.00
# end_total_asset: 1257169.84
# total_reward: 257169.84
# total_cost: 17862.57
# total_trades: 2128
# Sharpe: 0.524
# =================================
# Eval num_timesteps=96256, episode_reward=25.41 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 25.4     |
# | time/              |          |
# |    total_timesteps | 96256    |
# ---------------------------------
# Eval num_timesteps=98304, episode_reward=25.41 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 25.4     |
# | time/              |          |
# |    total_timesteps | 98304    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 258   |
# |    iterations      | 12    |
# |    time_elapsed    | 379   |
# |    total_timesteps | 98304 |
# ------------------------------
# day: 806, episode: 290
# begin_total_asset: 1000000.00
# end_total_asset: 1359196.65
# total_reward: 359196.65
# total_cost: 41872.76
# total_trades: 1589
# Sharpe: 0.619
# =================================
# Eval num_timesteps=100352, episode_reward=35.35 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 807          |
# |    mean_reward          | 35.4         |
# | time/                   |              |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0051016286 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.22        |
# |    explained_variance   | 0.204        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 14.4         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00155     |
# |    std                  | 0.986        |
# |    value_loss           | 29.9         |
# ------------------------------------------
# New best mean reward!
# Eval num_timesteps=102400, episode_reward=35.35 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 35.4     |
# | time/              |          |
# |    total_timesteps | 102400   |
# ---------------------------------
# Eval num_timesteps=104448, episode_reward=35.35 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 35.4     |
# | time/              |          |
# |    total_timesteps | 104448   |
# ---------------------------------
# day: 806, episode: 310
# begin_total_asset: 1000000.00
# end_total_asset: 1359196.65
# total_reward: 359196.65
# total_cost: 41872.76
# total_trades: 1589
# Sharpe: 0.619
# =================================
# Eval num_timesteps=106496, episode_reward=35.35 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 35.4     |
# | time/              |          |
# |    total_timesteps | 106496   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 258    |
# |    iterations      | 13     |
# |    time_elapsed    | 411    |
# |    total_timesteps | 106496 |
# -------------------------------
# Eval num_timesteps=108544, episode_reward=27.97 +/- 0.00
# Episode length: 807.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 807         |
# |    mean_reward          | 28          |
# | time/                   |             |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.004130866 |
# |    clip_fraction        | 0.0324      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.373       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.63        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00323    |
# |    std                  | 0.983       |
# |    value_loss           | 8.34        |
# -----------------------------------------
# day: 806, episode: 320
# begin_total_asset: 1000000.00
# end_total_asset: 1281408.01
# total_reward: 281408.01
# total_cost: 15283.16
# total_trades: 1532
# Sharpe: 0.594
# =================================
# Eval num_timesteps=110592, episode_reward=27.97 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 28       |
# | time/              |          |
# |    total_timesteps | 110592   |
# ---------------------------------
# Eval num_timesteps=112640, episode_reward=27.97 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 28       |
# | time/              |          |
# |    total_timesteps | 112640   |
# ---------------------------------
# Eval num_timesteps=114688, episode_reward=27.97 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 28       |
# | time/              |          |
# |    total_timesteps | 114688   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 258    |
# |    iterations      | 14     |
# |    time_elapsed    | 443    |
# |    total_timesteps | 114688 |
# -------------------------------
# day: 806, episode: 340
# begin_total_asset: 1000000.00
# end_total_asset: 1304040.44
# total_reward: 304040.44
# total_cost: 32165.66
# total_trades: 1992
# Sharpe: 0.510
# =================================
# Eval num_timesteps=116736, episode_reward=29.88 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 807          |
# |    mean_reward          | 29.9         |
# | time/                   |              |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0047499645 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.2         |
# |    explained_variance   | -0.00867     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 7.56         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000397    |
# |    std                  | 0.978        |
# |    value_loss           | 17.3         |
# ------------------------------------------
# Eval num_timesteps=118784, episode_reward=29.88 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 29.9     |
# | time/              |          |
# |    total_timesteps | 118784   |
# ---------------------------------
# day: 806, episode: 350
# begin_total_asset: 1000000.00
# end_total_asset: 1304040.44
# total_reward: 304040.44
# total_cost: 32165.66
# total_trades: 1992
# Sharpe: 0.510
# =================================
# Eval num_timesteps=120832, episode_reward=29.88 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 29.9     |
# | time/              |          |
# |    total_timesteps | 120832   |
# ---------------------------------
# Eval num_timesteps=122880, episode_reward=29.88 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 29.9     |
# | time/              |          |
# |    total_timesteps | 122880   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 258    |
# |    iterations      | 15     |
# |    time_elapsed    | 474    |
# |    total_timesteps | 122880 |
# -------------------------------
# Eval num_timesteps=124928, episode_reward=32.48 +/- 0.00
# Episode length: 807.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 807         |
# |    mean_reward          | 32.5        |
# | time/                   |             |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.005193899 |
# |    clip_fraction        | 0.0212      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | 0.26        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 14.1        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.000522   |
# |    std                  | 0.973       |
# |    value_loss           | 25.3        |
# -----------------------------------------
# day: 806, episode: 370
# begin_total_asset: 1000000.00
# end_total_asset: 1329780.45
# total_reward: 329780.45
# total_cost: 22723.95
# total_trades: 1951
# Sharpe: 0.557
# =================================
# Eval num_timesteps=126976, episode_reward=32.48 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 32.5     |
# | time/              |          |
# |    total_timesteps | 126976   |
# ---------------------------------
# Eval num_timesteps=129024, episode_reward=32.48 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 32.5     |
# | time/              |          |
# |    total_timesteps | 129024   |
# ---------------------------------
# day: 806, episode: 380
# begin_total_asset: 1000000.00
# end_total_asset: 1329780.45
# total_reward: 329780.45
# total_cost: 22723.95
# total_trades: 1951
# Sharpe: 0.557
# =================================
# Eval num_timesteps=131072, episode_reward=32.48 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 32.5     |
# | time/              |          |
# |    total_timesteps | 131072   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 258    |
# |    iterations      | 16     |
# |    time_elapsed    | 506    |
# |    total_timesteps | 131072 |
# -------------------------------
# Eval num_timesteps=133120, episode_reward=27.18 +/- 0.00
# Episode length: 807.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 807         |
# |    mean_reward          | 27.2        |
# | time/                   |             |
# |    total_timesteps      | 133120      |
# | train/                  |             |
# |    approx_kl            | 0.004724301 |
# |    clip_fraction        | 0.0424      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | -0.00115    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.54        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.000734   |
# |    std                  | 0.963       |
# |    value_loss           | 16.7        |
# -----------------------------------------
# Eval num_timesteps=135168, episode_reward=27.18 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 27.2     |
# | time/              |          |
# |    total_timesteps | 135168   |
# ---------------------------------
# day: 806, episode: 400
# begin_total_asset: 1000000.00
# end_total_asset: 1276762.51
# total_reward: 276762.51
# total_cost: 25707.37
# total_trades: 1904
# Sharpe: 0.482
# =================================
# Eval num_timesteps=137216, episode_reward=27.18 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 27.2     |
# | time/              |          |
# |    total_timesteps | 137216   |
# ---------------------------------
# Eval num_timesteps=139264, episode_reward=27.18 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 27.2     |
# | time/              |          |
# |    total_timesteps | 139264   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 258    |
# |    iterations      | 17     |
# |    time_elapsed    | 538    |
# |    total_timesteps | 139264 |
# -------------------------------
# day: 806, episode: 410
# begin_total_asset: 1000000.00
# end_total_asset: 1165633.31
# total_reward: 165633.31
# total_cost: 23115.93
# total_trades: 2161
# Sharpe: 0.414
# =================================
# Eval num_timesteps=141312, episode_reward=16.41 +/- 0.00
# Episode length: 807.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 807         |
# |    mean_reward          | 16.4        |
# | time/                   |             |
# |    total_timesteps      | 141312      |
# | train/                  |             |
# |    approx_kl            | 0.004402645 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.263       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.3        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00113    |
# |    std                  | 0.965       |
# |    value_loss           | 38.6        |
# -----------------------------------------
# Eval num_timesteps=143360, episode_reward=16.41 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 16.4     |
# | time/              |          |
# |    total_timesteps | 143360   |
# ---------------------------------
# Eval num_timesteps=145408, episode_reward=16.41 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 16.4     |
# | time/              |          |
# |    total_timesteps | 145408   |
# ---------------------------------
# day: 806, episode: 430
# begin_total_asset: 1000000.00
# end_total_asset: 1165633.31
# total_reward: 165633.31
# total_cost: 23115.93
# total_trades: 2161
# Sharpe: 0.414
# =================================
# Eval num_timesteps=147456, episode_reward=16.41 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 16.4     |
# | time/              |          |
# |    total_timesteps | 147456   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 258    |
# |    iterations      | 18     |
# |    time_elapsed    | 569    |
# |    total_timesteps | 147456 |
# -------------------------------
# Eval num_timesteps=149504, episode_reward=30.34 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 807          |
# |    mean_reward          | 30.3         |
# | time/                   |              |
# |    total_timesteps      | 149504       |
# | train/                  |              |
# |    approx_kl            | 0.0050270865 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.14        |
# |    explained_variance   | 0.163        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.33         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00241     |
# |    std                  | 0.961        |
# |    value_loss           | 12           |
# ------------------------------------------
# day: 806, episode: 440
# begin_total_asset: 1000000.00
# end_total_asset: 1308556.78
# total_reward: 308556.78
# total_cost: 22482.26
# total_trades: 1669
# Sharpe: 0.514
# =================================
# Eval num_timesteps=151552, episode_reward=30.34 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 30.3     |
# | time/              |          |
# |    total_timesteps | 151552   |
# ---------------------------------
# Eval num_timesteps=153600, episode_reward=30.34 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 30.3     |
# | time/              |          |
# |    total_timesteps | 153600   |
# ---------------------------------
# Eval num_timesteps=155648, episode_reward=30.34 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 30.3     |
# | time/              |          |
# |    total_timesteps | 155648   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 258    |
# |    iterations      | 19     |
# |    time_elapsed    | 602    |
# |    total_timesteps | 155648 |
# -------------------------------
# day: 806, episode: 460
# begin_total_asset: 1000000.00
# end_total_asset: 1249334.97
# total_reward: 249334.97
# total_cost: 29746.38
# total_trades: 1703
# Sharpe: 0.452
# =================================
# Eval num_timesteps=157696, episode_reward=24.44 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 807          |
# |    mean_reward          | 24.4         |
# | time/                   |              |
# |    total_timesteps      | 157696       |
# | train/                  |              |
# |    approx_kl            | 0.0053558014 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.12        |
# |    explained_variance   | 0.0042       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 20.2         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00124     |
# |    std                  | 0.952        |
# |    value_loss           | 40.5         |
# ------------------------------------------
# Eval num_timesteps=159744, episode_reward=24.44 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 24.4     |
# | time/              |          |
# |    total_timesteps | 159744   |
# ---------------------------------
# day: 806, episode: 470
# begin_total_asset: 1000000.00
# end_total_asset: 1249334.97
# total_reward: 249334.97
# total_cost: 29746.38
# total_trades: 1703
# Sharpe: 0.452
# =================================
# Eval num_timesteps=161792, episode_reward=24.44 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# ...
# |    mean_ep_length  | 807      |
# |    mean_reward     | 35       |
# | time/              |          |
# |    total_timesteps | 253952   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 257    |
# |    iterations      | 31     |
# |    time_elapsed    | 984    |
# |    total_timesteps | 253952 |
# -------------------------------
# Eval num_timesteps=256000, episode_reward=34.67 +/- 0.00
# Episode length: 807.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 807         |
# |    mean_reward          | 34.7        |
# | time/                   |             |
# |    total_timesteps      | 256000      |
# | train/                  |             |
# |    approx_kl            | 0.002894104 |
# |    clip_fraction        | 0.0147      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.99       |
# |    explained_variance   | 0.171       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 20.9        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00137    |
# |    std                  | 0.916       |
# |    value_loss           | 38.4        |
# -----------------------------------------
# Eval num_timesteps=258048, episode_reward=34.67 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 34.7     |
# | time/              |          |
# |    total_timesteps | 258048   |
# ---------------------------------
# day: 806, episode: 760
# begin_total_asset: 1000000.00
# end_total_asset: 1351171.16
# total_reward: 351171.16
# total_cost: 14775.30
# total_trades: 2341
# Sharpe: 0.575
# =================================
# Eval num_timesteps=260096, episode_reward=34.67 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 34.7     |
# | time/              |          |
# |    total_timesteps | 260096   |
# ---------------------------------
# Eval num_timesteps=262144, episode_reward=34.67 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 34.7     |
# | time/              |          |
# |    total_timesteps | 262144   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 257    |
# |    iterations      | 32     |
# |    time_elapsed    | 1016   |
# |    total_timesteps | 262144 |
# -------------------------------
# day: 806, episode: 770
# begin_total_asset: 1000000.00
# end_total_asset: 1355202.22
# total_reward: 355202.22
# total_cost: 14777.60
# total_trades: 2347
# Sharpe: 0.590
# =================================
# Eval num_timesteps=264192, episode_reward=35.10 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 807          |
# |    mean_reward          | 35.1         |
# | time/                   |              |
# |    total_timesteps      | 264192       |
# | train/                  |              |
# |    approx_kl            | 0.0064367917 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.98        |
# |    explained_variance   | 0.406        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.35         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00171     |
# |    std                  | 0.91         |
# |    value_loss           | 10.9         |
# ------------------------------------------
# Eval num_timesteps=266240, episode_reward=35.10 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 35.1     |
# | time/              |          |
# |    total_timesteps | 266240   |
# ---------------------------------
# Eval num_timesteps=268288, episode_reward=35.10 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 35.1     |
# | time/              |          |
# |    total_timesteps | 268288   |
# ---------------------------------
# day: 806, episode: 790
# begin_total_asset: 1000000.00
# end_total_asset: 1355202.22
# total_reward: 355202.22
# total_cost: 14777.60
# total_trades: 2347
# Sharpe: 0.590
# =================================
# Eval num_timesteps=270336, episode_reward=35.10 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 35.1     |
# | time/              |          |
# |    total_timesteps | 270336   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 257    |
# |    iterations      | 33     |
# |    time_elapsed    | 1048   |
# |    total_timesteps | 270336 |
# -------------------------------
# Eval num_timesteps=272384, episode_reward=34.85 +/- 0.00
# Episode length: 807.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 807         |
# |    mean_reward          | 34.8        |
# | time/                   |             |
# |    total_timesteps      | 272384      |
# | train/                  |             |
# |    approx_kl            | 0.003012323 |
# |    clip_fraction        | 0.023       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | -0.00217    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.76        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.000872   |
# |    std                  | 0.907       |
# |    value_loss           | 18.4        |
# -----------------------------------------
# day: 806, episode: 800
# begin_total_asset: 1000000.00
# end_total_asset: 1352353.47
# total_reward: 352353.47
# total_cost: 14794.79
# total_trades: 2345
# Sharpe: 0.600
# =================================
# Eval num_timesteps=274432, episode_reward=34.85 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 34.8     |
# | time/              |          |
# |    total_timesteps | 274432   |
# ---------------------------------
# Eval num_timesteps=276480, episode_reward=34.85 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 34.8     |
# | time/              |          |
# |    total_timesteps | 276480   |
# ---------------------------------
# Eval num_timesteps=278528, episode_reward=34.85 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 34.8     |
# | time/              |          |
# |    total_timesteps | 278528   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 257    |
# |    iterations      | 34     |
# |    time_elapsed    | 1080   |
# |    total_timesteps | 278528 |
# -------------------------------
# day: 806, episode: 820
# begin_total_asset: 1000000.00
# end_total_asset: 1364336.06
# total_reward: 364336.06
# total_cost: 14848.39
# total_trades: 2212
# Sharpe: 0.616
# =================================
# Eval num_timesteps=280576, episode_reward=36.05 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 807          |
# |    mean_reward          | 36           |
# | time/                   |              |
# |    total_timesteps      | 280576       |
# | train/                  |              |
# |    approx_kl            | 0.0035273447 |
# |    clip_fraction        | 0.0276       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.95        |
# |    explained_variance   | 0.331        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 13.3         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00253     |
# |    std                  | 0.902        |
# |    value_loss           | 28           |
# ------------------------------------------
# Eval num_timesteps=282624, episode_reward=36.05 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 36       |
# | time/              |          |
# |    total_timesteps | 282624   |
# ---------------------------------
# day: 806, episode: 830
# begin_total_asset: 1000000.00
# end_total_asset: 1364336.06
# total_reward: 364336.06
# total_cost: 14848.39
# total_trades: 2212
# Sharpe: 0.616
# =================================
# Eval num_timesteps=284672, episode_reward=36.05 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 36       |
# | time/              |          |
# |    total_timesteps | 284672   |
# ---------------------------------
# Eval num_timesteps=286720, episode_reward=36.05 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 36       |
# | time/              |          |
# |    total_timesteps | 286720   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 257    |
# |    iterations      | 35     |
# |    time_elapsed    | 1112   |
# |    total_timesteps | 286720 |
# -------------------------------
# Eval num_timesteps=288768, episode_reward=36.38 +/- 0.00
# Episode length: 807.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 807         |
# |    mean_reward          | 36.4        |
# | time/                   |             |
# |    total_timesteps      | 288768      |
# | train/                  |             |
# |    approx_kl            | 0.004770809 |
# |    clip_fraction        | 0.0426      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.92       |
# |    explained_variance   | -0.0184     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.22        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00123    |
# |    std                  | 0.888       |
# |    value_loss           | 14.9        |
# -----------------------------------------
# day: 806, episode: 850
# begin_total_asset: 1000000.00
# end_total_asset: 1367586.02
# total_reward: 367586.02
# total_cost: 14777.73
# total_trades: 2359
# Sharpe: 0.623
# =================================
# Eval num_timesteps=290816, episode_reward=36.38 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 36.4     |
# | time/              |          |
# |    total_timesteps | 290816   |
# ---------------------------------
# Eval num_timesteps=292864, episode_reward=36.38 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 36.4     |
# | time/              |          |
# |    total_timesteps | 292864   |
# ---------------------------------
# day: 806, episode: 860
# begin_total_asset: 1000000.00
# end_total_asset: 1367586.02
# total_reward: 367586.02
# total_cost: 14777.73
# total_trades: 2359
# Sharpe: 0.623
# =================================
# Eval num_timesteps=294912, episode_reward=36.38 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 36.4     |
# | time/              |          |
# |    total_timesteps | 294912   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 257    |
# |    iterations      | 36     |
# |    time_elapsed    | 1144   |
# |    total_timesteps | 294912 |
# -------------------------------
# Eval num_timesteps=296960, episode_reward=36.06 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 807          |
# |    mean_reward          | 36.1         |
# | time/                   |              |
# |    total_timesteps      | 296960       |
# | train/                  |              |
# |    approx_kl            | 0.0023494174 |
# |    clip_fraction        | 0.00881      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.9         |
# |    explained_variance   | 0.264        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 11.7         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00118     |
# |    std                  | 0.887        |
# |    value_loss           | 36.6         |
# ------------------------------------------
# Eval num_timesteps=299008, episode_reward=36.06 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 36.1     |
# | time/              |          |
# |    total_timesteps | 299008   |
# ---------------------------------
# day: 806, episode: 880
# begin_total_asset: 1000000.00
# end_total_asset: 1364294.89
# total_reward: 364294.89
# total_cost: 14776.77
# total_trades: 2350
# Sharpe: 0.622
# =================================
# Eval num_timesteps=301056, episode_reward=36.06 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 36.1     |
# | time/              |          |
# |    total_timesteps | 301056   |
# ---------------------------------
# Eval num_timesteps=303104, episode_reward=36.06 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 36.1     |
# | time/              |          |
# |    total_timesteps | 303104   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 257    |
# |    iterations      | 37     |
# |    time_elapsed    | 1175   |
# |    total_timesteps | 303104 |
# -------------------------------
# 💾 บันทึกโมเดลเสร็จสิ้น! บอทเวอร์ชันที่ดีที่สุดถูกบรรจุอยู่ในโฟลเดอร์ './best_model/'
#
# 🔮 ดึงข้อมูลตลาดปัจจุบันมาสับไพ่ทดสอบจริง (Out-of-Sample Test)...
# 📦 กําลังดาวน์โหลดข้อมูลจาก 2024-01-01 ถึง 2026-07-29...
# ℹ️ ตัดแถวที่มี NaN (ช่วง warm-up ของ indicator/publication lag) ออก 597 แถว
# 📁 [Exported] บันทึกไฟล์ Test Set เรียบร้อย -> ./exported_data/test_set.csv
# 📈 บอทกำลังดำเนินการจำลองการกระจายสินทรัพย์จริงในอดีต...
# 🏁 การทดสอบย้อนหลังสิ้นสุดสมบูรณ์!
#
# =======================================================
# 🤖 สรุปผลงานบอทเทรดในหน้าต่างทดสอบจริง (ฉบับเข้าใจง่าย)
# =======================================================
#
# 💰 1. ด้านการทำกำไร (Return)
#    • กำไรสะสมตลอดการทดสอบ: 29.39%
#    • ผลตอบแทนทบต้นเฉลี่ยรายปี (CAGR): 15.75%
#    ✅ สรุป: ยอดเยี่ยม! บอทสร้างผลงานชนะอัตราเฉลี่ยของตลาดส่วนใหญ่
#
# 📉 2. ด้านความเสี่ยง (Risk & Drawdown)
#    • ช่วงที่พอร์ตร่วงหนักสุดจากจุดสูงสุด (Max Drawdown): -21.15%
#    ⚠️ สรุป: ปานกลาง พอร์ตแกว่งตามมาตรฐานสไตล์กองทุนเชิงรุก
#
# ⚖️ 3. ความคุ้มค่าและสถิติการชนะ (Efficiency)
#    • ความคุ้มค่าต่อหนึ่งหน่วยความเสี่ยง (Sharpe Ratio): 0.84
#    ⚠️ สรุป: ความคุ้มค่าน้อยลง ผลตอบแทนอาจไม่สมน้ำสมเนื้อกับความเสี่ยงที่เผชิญ
#    • อัตราความแม่นยำรายวัน (Win Rate): 54.95%
# =======================================================
