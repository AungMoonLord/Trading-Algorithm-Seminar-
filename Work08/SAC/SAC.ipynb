# %%
import pandas as pd
import yfinance as yf
import ta
import pandas_datareader.data as web
import numpy as np
import torch
import quantstats as qs
import os
import json
import warnings

warnings.filterwarnings('ignore')

from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback

# 📌 [แก้ตรงนี้: เปลี่ยนการอิมพอร์ตจาก PPO เป็น SAC]
from stable_baselines3 import SAC

# %%
# ==========================================
# 0. HARDWARE SETUP
# ==========================================
device = "cpu"
print(f"✅ Device Strategy: '{device}' เพราะ PPO+MlpPolicy เป็นโมเดลเล็ก การใช้ GPU จะช้ากว่าเพราะ overhead การส่งข้อมูล")
if torch.cuda.is_available():
    print(f"   - พบ GPU: {torch.cuda.get_device_name(0)} (แต่ไม่แนะนำให้ใช้กับ PPO MlpPolicy)")
else:
    print("   - ไม่พบการ์ดจอแยก ระบบจะทำงานบน CPU")
# Out:
# ✅ Device Strategy: 'cpu' เพราะ PPO+MlpPolicy เป็นโมเดลเล็ก การใช้ GPU จะช้ากว่าเพราะ overhead การส่งข้อมูล
#    - ไม่พบการ์ดจอแยก ระบบจะทำงานบน CPU

# %%
# ==========================================
# 1. GLOBAL CONFIGURATION
# ==========================================
TICKERS = ['DIA', 'QQQ', 'SPY']
TRANSACTION_COST_PCT = 0.003

FED_FUNDS_LAG_DAYS = 30   
M2_LAG_DAYS = 21          

USE_MULTI_TIMEFRAME = True # แนะนำให้เปิดได้แล้ว เพราะแก้ปัญหาเรื่อง NaN Buffer แล้ว

# แก้ไข #1: เปลี่ยนโครงสร้าง Technical Indicators ให้เป็น Stationary ทั้งหมด (ไม่มีราคาดิบเจือปน)
# - ถอด EMA_12, 26, 50, 200 (ที่เป็นราคาดิบ) ออกทั้งหมด
# - ใช้สัดส่วน (Ratio) และเปอร์เซ็นต์ (Pct) แทน เพื่อให้ค่าแกว่งตัวในกรอบแคบและสเกลคงที่ไม่ว่าราคาหุ้นจะ 100 หรือ 500
COMPLETE_TECHNICAL_INDICATORS = [
    'RSI_14', 'RSI_signal', 'RSI_overbought', 'RSI_oversold', 'RSI_above_center',
    'MACD_line_pct', 'MACD_signal_pct', 'MACD_hist_pct', 'MACD_cross',
    'EMA_12_26_ratio', 'EMA_50_200_ratio', 'price_to_EMA50_ratio', 'price_to_EMA200_ratio',
    'EMA_golden_cross', 'EMA_death_cross',
    'StochRSI_K', 'StochRSI_D', 'StochRSI_cross',
]

MULTI_TIMEFRAME_INDICATORS = [
    'RSI_weekly', 'RSI_monthly',
    'MACD_hist_weekly_pct', 'MACD_hist_monthly_pct',
]

MACRO_INDICATORS = ['vix', 'bond_yield', 'gold', 'wti', 'fed_rate', 'm2']

TECHNICAL_INDICATORS = COMPLETE_TECHNICAL_INDICATORS + (
    MULTI_TIMEFRAME_INDICATORS if USE_MULTI_TIMEFRAME else []
)
FEATURES = TECHNICAL_INDICATORS + MACRO_INDICATORS

# %%
# ==========================================
# 2. INDICATOR COMPUTATION (Stationary & Scaled)
# ==========================================
def compute_complete_indicators(df, price_col='close'):
    close = df[price_col]

    # แก้ไข #2: Normalize RSI ให้ร่วงมาอยู่ในกรอบ [0, 1] เสมอ
    rsi = ta.momentum.RSIIndicator(close=close, window=14).rsi()
    df['RSI_14'] = rsi / 100.0 
    df['RSI_signal'] = rsi.rolling(window=9).mean() / 100.0
    df['RSI_overbought'] = (rsi > 70).astype(float)
    df['RSI_oversold'] = (rsi < 30).astype(float)
    df['RSI_above_center'] = (rsi > 50).astype(float)

    # แก้ไข #3: แปลง MACD เป็น PPOscillator (หารด้วย EMA26) ป้องกันโมเดลช็อกถ้าราคาพุ่งไป 500+
    ema26 = ta.trend.EMAIndicator(close=close, window=26).ema_indicator()
    macd_obj = ta.trend.MACD(close=close, window_slow=26, window_fast=12, window_sign=9)
    macd_line = macd_obj.macd()
    macd_signal = macd_obj.macd_signal()
    
    df['MACD_line_pct'] = macd_line / ema26
    df['MACD_signal_pct'] = macd_signal / ema26
    df['MACD_hist_pct'] = macd_obj.macd_diff() / ema26
    
    prev_diff = (macd_line - macd_signal).shift(1)
    curr_diff = macd_line - macd_signal
    df['MACD_cross'] = np.select(
        [(prev_diff <= 0) & (curr_diff > 0), (prev_diff >= 0) & (curr_diff < 0)],
        [1.0, -1.0], default=0.0
    )

    # แก้ไข #4: เปลี่ยน EMA ดิบเป็น EMA Ratio (Stationary Feature) เพื่อไม่ให้ Gradient ระเบิด
    ema12 = ta.trend.EMAIndicator(close=close, window=12).ema_indicator()
    ema50 = ta.trend.EMAIndicator(close=close, window=50).ema_indicator()
    ema200 = ta.trend.EMAIndicator(close=close, window=200).ema_indicator()
    
    df['EMA_12_26_ratio'] = (ema12 - ema26) / ema26
    df['EMA_50_200_ratio'] = (ema50 - ema200) / ema200
    df['price_to_EMA50_ratio'] = (close - ema50) / ema50
    df['price_to_EMA200_ratio'] = (close - ema200) / ema200
    
    prev_ema_diff = (ema50 - ema200).shift(1)
    curr_ema_diff = ema50 - ema200
    df['EMA_golden_cross'] = ((prev_ema_diff <= 0) & (curr_ema_diff > 0)).astype(float)
    df['EMA_death_cross'] = ((prev_ema_diff >= 0) & (curr_ema_diff < 0)).astype(float)

    # StochRSI มีกรอบ 0-1 ในตัวมันเองอยู่แล้ว ไม่ต้องหารเพิ่ม
    stochrsi_obj = ta.momentum.StochRSIIndicator(close=close, window=14, smooth1=3, smooth2=3)
    stoch_k = stochrsi_obj.stochrsi_k()
    stoch_d = stochrsi_obj.stochrsi_d()
    df['StochRSI_K'] = stoch_k
    df['StochRSI_D'] = stoch_d
    prev_stoch_diff = (stoch_k - stoch_d).shift(1)
    curr_stoch_diff = stoch_k - stoch_d
    bullish_cross = (prev_stoch_diff <= 0) & (curr_stoch_diff > 0) & (stoch_k < 0.2)
    bearish_cross = (prev_stoch_diff >= 0) & (curr_stoch_diff < 0) & (stoch_k > 0.8)
    df['StochRSI_cross'] = np.select([bullish_cross, bearish_cross], [1.0, -1.0], default=0.0)

    return df


def compute_multi_timeframe_features(df, price_col='close', date_col='date'):
    df = df.copy()
    df[date_col] = pd.to_datetime(df[date_col])
    df = df.set_index(date_col).sort_index()
    close = df[price_col]

    weekly_close = close.resample('W-FRI').last()
    weekly_rsi = ta.momentum.RSIIndicator(close=weekly_close, window=14).rsi().shift(1)
    df['RSI_weekly'] = (weekly_rsi / 100.0).reindex(df.index, method='ffill')

    weekly_macd_hist = ta.trend.MACD(close=weekly_close).macd_diff().shift(1)
    # ทำ MACD ให้เป็น Percent (หารด้วยราคาก่อนหน้า)
    df['MACD_hist_weekly_pct'] = (weekly_macd_hist / weekly_close.shift(1)).reindex(df.index, method='ffill')

    monthly_close = close.resample('ME').last()
    monthly_rsi = ta.momentum.RSIIndicator(close=monthly_close, window=14).rsi().shift(1)
    df['RSI_monthly'] = (monthly_rsi / 100.0).reindex(df.index, method='ffill')

    monthly_macd_hist = ta.trend.MACD(close=monthly_close).macd_diff().shift(1)
    df['MACD_hist_monthly_pct'] = (monthly_macd_hist / monthly_close.shift(1)).reindex(df.index, method='ffill')

    df = df.reset_index()
    return df

# %%
# ==========================================
# 3. HIGH-PERFORMANCE DATA PIPELINE
# ==========================================
# แก้ไข #5: เพิ่มพารามิเตอร์ trim_start สำหรับการทำ Lookback Buffer
# เพื่อให้เราดึงข้อมูลย้อนหลังไปไกลๆ ได้ (warm-up indicator) แล้วค่อยตัดเฉพาะช่วง Test จริงทีหลัง
def fetch_and_prepare_data(tickers, start_date, end_date, trim_start=None):
    print(f"📦 กําลังดาวน์โหลดข้อมูลจาก {start_date} ถึง {end_date}...")
    processed_dfs = []

    for ticker in tickers:
        try:
            df = yf.download(ticker, start=start_date, end=end_date, progress=False)
            if df.empty:
                continue

            df.columns = [col[0] if isinstance(col, tuple) else col for col in df.columns]
            df = df.reset_index()
            df.rename(columns={'Date': 'date', 'Open': 'open', 'High': 'high', 'Low': 'low',
                                'Close': 'close', 'Volume': 'volume'}, inplace=True)
            df['tic'] = ticker
            df = compute_complete_indicators(df, price_col='close')

            if USE_MULTI_TIMEFRAME:
                df = compute_multi_timeframe_features(df, price_col='close', date_col='date')

            processed_dfs.append(df)
        except Exception as e:
            print(f"❌ ไม่สามารถดาวน์โหลด {ticker}: {e}")

    if not processed_dfs:
        raise ValueError("ดาวน์โหลดข้อมูลล้มเหลว กรุณาตรวจสอบการเชื่อมต่ออินเทอร์เน็ต")

    final_df = pd.concat(processed_dfs, ignore_index=True)

    macro_tickers = {"^VIX": "vix", "^TNX": "bond_yield", "GC=F": "gold", "CL=F": "wti"}
    try:
        macro_raw = yf.download(list(macro_tickers.keys()), start=start_date, end=end_date, progress=False)
        macro_df = macro_raw['Close'].copy()
        macro_df.columns = [col[0] if isinstance(col, tuple) else col for col in macro_df.columns]
        macro_df.rename(columns=macro_tickers, inplace=True)
        macro_df = macro_df.reset_index().rename(columns={'Date': 'date'})
        final_df = pd.merge(final_df, macro_df, on='date', how='left')
    except:
        for name in macro_tickers.values():
            final_df[name] = np.nan

    try:
        fed_funds = web.DataReader('FEDFUNDS', 'fred', start_date, end_date).reset_index()
        m2_supply = web.DataReader('M2SL', 'fred', start_date, end_date).reset_index()
        fed_funds.rename(columns={'DATE': 'date', 'FEDFUNDS': 'fed_rate'}, inplace=True)
        m2_supply.rename(columns={'DATE': 'date', 'M2SL': 'm2'}, inplace=True)

        fed_funds['date'] = fed_funds['date'] + pd.Timedelta(days=FED_FUNDS_LAG_DAYS)
        m2_supply['date'] = m2_supply['date'] + pd.Timedelta(days=M2_LAG_DAYS)

        macro_fred = pd.merge(fed_funds, m2_supply, on='date', how='outer')
        final_df = pd.merge(final_df, macro_fred, on='date', how='left')
    except:
        final_df['fed_rate'] = np.nan
        final_df['m2'] = np.nan

    final_df.sort_values(['date', 'tic'], inplace=True)

    numeric_cols = final_df.select_dtypes(include=[np.number]).columns.tolist()
    numeric_cols = [c for c in numeric_cols if c != 'day']
    final_df[numeric_cols] = final_df.groupby('tic')[numeric_cols].ffill()

    if USE_MULTI_TIMEFRAME:
        for col in MULTI_TIMEFRAME_INDICATORS:
            if col in final_df.columns:
                final_df[col] = final_df[col].fillna(0.0)

    final_df.dropna(inplace=True)
    
    # แก้ไข #6: ตัดข้อมูลเฉพาะช่วงทดสอบจริง (หลัง Warm-up เสร็จ) เพื่อลดปัญหา NaN 100% 
    if trim_start is not None:
        final_df = final_df[final_df['date'] >= pd.to_datetime(trim_start)]
        print(f"✂️ หั่น Lookback Buffer ทิ้ง เหลือข้อมูลใช้งานจริงตั้งแต่: {trim_start}")

    # รัน index วันที่ 'day' ใหม่หลังจากตัด Buffer ออก เพื่อให้ Env Index ไม่เพี้ยน
    date_list = sorted(final_df['date'].unique())
    date2day = {date: day for day, date in enumerate(date_list)}
    final_df['day'] = final_df['date'].map(date2day)
    final_df['date'] = final_df['date'].dt.strftime('%Y-%m-%d')

    final_df = final_df.sort_values(['date', 'tic'])
    final_df.index = final_df['day'].values
    return final_df


# แก้ไข #7: ปรับโครงสร้างระบบ Normalization ขยายการครอบคลุม
# นำเอา Continuous Features ทั้ง Macro และ Technical เข้าสู่กระบวนการ Z-Score
def compute_feature_scaling_stats(train_df):
    scale_cols = [
        # Macro
        'm2', 'fed_rate', 'vix', 'bond_yield', 'gold', 'wti',
        # Continuous Technical (Ratios & Percentages)
        'MACD_line_pct', 'MACD_signal_pct', 'MACD_hist_pct',
        'EMA_12_26_ratio', 'EMA_50_200_ratio', 
        'price_to_EMA50_ratio', 'price_to_EMA200_ratio'
    ]
    if USE_MULTI_TIMEFRAME:
        scale_cols.extend(['MACD_hist_weekly_pct', 'MACD_hist_monthly_pct'])

    stats = {}
    for col in scale_cols:
        if col in train_df.columns:
            mean = train_df[col].mean()
            std = train_df[col].std()
            std = std if std > 1e-8 else 1.0
            stats[col] = (mean, std)
    return stats


def apply_feature_scaling(df, stats):
    df = df.copy()
    for col, (mean, std) in stats.items():
        if col in df.columns:
            df[col] = (df[col] - mean) / std
    return df

# %%
# ==========================================
# 4. ROBUST CUSTOM ENVIRONMENT
# ==========================================
class RealisticTradingEnv(StockTradingEnv):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.vix_array = self.df['vix'].values if 'vix' in self.df.columns else np.zeros(len(self.df))
        
        # [ใหม่ 1/3] สร้างตัวแปรจำจุดสูงสุดของพอร์ตตอนเริ่ม Environment
        self.peak_portfolio_value = self.initial_amount

    # [ใหม่ 2/3] ต้อง Override ฟังก์ชัน reset() เพื่อล้างค่า Peak กลับเป็นทุนเริ่มต้นทุกครั้งที่เริ่มรอบใหม่
    # [แก้ไข] เพิ่ม **kwargs เพื่อรับพารามิเตอร์ซ่อนเร้นจาก Stable-Baselines3
    def reset(self,**kwargs):
        # โยน **kwargs ส่งต่อไปให้คลาสแม่ (FinRL) จัดการ
        state = super().reset(**kwargs) # เรียกใช้ reset ของคลาสแม่ (FinRL)
        self.peak_portfolio_value = self.initial_amount # ล้างค่า High Water Mark
        return state
    
    def _calculate_reward(self):
        current_portfolio_value = self.state[0] + sum(
            np.array(self.state[1:(self.stock_dim + 1)]) *
            np.array(self.state[(self.stock_dim + 1):(self.stock_dim * 2 + 1)])
        )

        # [ใหม่ 3/3] อัปเดตจุดสูงสุดของพอร์ต (High Water Mark) แบบ Real-time
        if current_portfolio_value > self.peak_portfolio_value:
            self.peak_portfolio_value = current_portfolio_value

        previous_portfolio_value = self.asset_memory[-1] if len(self.asset_memory) > 0 else self.initial_amount
        if previous_portfolio_value <= 0:
            previous_portfolio_value = self.initial_amount

        step_return = (current_portfolio_value - previous_portfolio_value) / previous_portfolio_value

        # Asymmetric Reward ขาลง (หักคะแนนหนักกว่าตอนได้กำไร 50%)

        ASYMMETRY_FACTOR = 1.5
        if step_return < 0:
            step_return *= ASYMMETRY_FACTOR

        current_vix = self.vix_array[self.day] if self.day < len(self.vix_array) else 0.0
        invested_ratio = 1 - (self.state[0] / current_portfolio_value) if current_portfolio_value > 0 else 0

        # Risk Penalty จาก VIX
        risk_penalty = 0.0 
        if current_vix > 0.0:  # Z-score > 0 (VIX สูงกว่าค่าเฉลี่ยใน Training Set)
            vix_excess = current_vix / 10.0
            risk_penalty = vix_excess * invested_ratio * (abs(step_return) + 0.001)

        # ค่าเสียโอกาสหากถือเงินสดตอนตลาดปกติ
        cash_opportunity_cost = 0.0
        if invested_ratio < 0.05 and current_vix <= 0.0:
            cash_opportunity_cost = 0.02 

        # คำนวณ Reward เบื้องต้น (สเกล * 100 เพื่อให้ตัวเลขอยู่ในช่วงประมาณ -5 ถึง +5)
        raw_reward = (step_return * 100) - (risk_penalty * 100) - cash_opportunity_cost


        # สมมติเราเก็บค่าจุดสูงสุดของพอร์ตไว้ (self.peak_portfolio_value)

        current_drawdown = (current_portfolio_value - self.peak_portfolio_value) / self.peak_portfolio_value

        # ---------------------------------------------------------
        # 🚨 ส่วนที่เพิ่ม: DRAWDOWN PENALTY (ลงโทษเมื่อพอร์ตร่วงจากจุดสูงสุด)
        # ---------------------------------------------------------

        current_drawdown = (current_portfolio_value - self.peak_portfolio_value) / self.peak_portfolio_value
        # ถ้า Drawdown เริ่มลึกกว่า -5% ให้หักคะแนนหนักขึ้นเรื่อยๆ แบบ Exponential
        if current_drawdown < -0.05:
            dd_penalty = (abs(current_drawdown) - 0.05) * 10 
            raw_reward -= dd_penalty
        # ---------------------------------------------------------

        # ใช้ tanh ตัดขอบ reward ให้อยู่ในช่วง -10 ถึง +10 (ป้องกัน Gradient ระเบิดเวลาตลาดพังหนัก)
        reward = 10.0 * np.tanh(raw_reward / 10.0)

        return float(reward)


def get_env_kwargs(stock_dimension):
    state_space = 1 + (2 * stock_dimension) + (len(FEATURES) * stock_dimension)
    return {
        "hmax": 100,
        "initial_amount": 1000000,
        "num_stock_shares": [0] * stock_dimension,
        "state_space": state_space,
        "stock_dim": stock_dimension,
        "tech_indicator_list": FEATURES,
        "action_space": stock_dimension,
        "reward_scaling": 1e-4,
        "buy_cost_pct": [TRANSACTION_COST_PCT] * stock_dimension,
        "sell_cost_pct": [TRANSACTION_COST_PCT] * stock_dimension,
    }

# %%
# ==========================================
# 5. TRANSLATION & REPORT ENGINE
# ==========================================
def explain_bot_performance(returns):
    print("\n" + "=" * 55)
    print("🤖 สรุปผลงานบอทเทรดในหน้าต่างทดสอบจริง (ฉบับเข้าใจง่าย)")
    print("=" * 55)

    total_return = qs.stats.comp(returns) * 100
    cagr = qs.stats.cagr(returns) * 100
    max_dd = qs.stats.max_drawdown(returns) * 100
    sharpe = qs.stats.sharpe(returns)
    win_rate = qs.stats.win_rate(returns) * 100

    print("\n💰 1. ด้านการทำกำไร (Return)")
    print(f"   • กำไรสะสมตลอดการทดสอบ: {total_return:.2f}%")
    print(f"   • ผลตอบแทนทบต้นเฉลี่ยรายปี (CAGR): {cagr:.2f}%")
    if cagr > 12:
        print("   ✅ สรุป: ยอดเยี่ยม! บอทสร้างผลงานชนะอัตราเฉลี่ยของตลาดส่วนใหญ่")
    elif cagr > 0:
        print("   ⚠️ สรุป: พอใช้ได้ พอร์ตโตขึ้นแต่ยังไม่โดดเด่นนัก")
    else:
        print("   ❌ สรุป: ล้มเหลว บอททำเงินต้นสูญหาย")

    print("\n📉 2. ด้านความเสี่ยง (Risk & Drawdown)")
    print(f"   • ช่วงที่พอร์ตร่วงหนักสุดจากจุดสูงสุด (Max Drawdown): {max_dd:.2f}%")
    if max_dd > -15:
        print("   ✅ สรุป: ปลอดภัยสูง ระบบคุมสัดส่วนการสูญเสียเงินได้ดีมาก")
    elif max_dd > -30:
        print("   ⚠️ สรุป: ปานกลาง พอร์ตแกว่งตามมาตรฐานสไตล์กองทุนเชิงรุก")
    else:
        print("   ❌ สรุป: อันตรายมาก! บอทปล่อยให้พอร์ตเสียหายหนักเกินไป")

    print("\n⚖️ 3. ความคุ้มค่าและสถิติการชนะ (Efficiency)")
    print(f"   • ความคุ้มค่าต่อหนึ่งหน่วยความเสี่ยง (Sharpe Ratio): {sharpe:.2f}")
    if sharpe >= 1.0:
        print("   ✅ สรุป: ดีเยี่ยม กำไรที่ได้คุ้มค่าอย่างมากกับความเสี่ยงที่ถือครอง")
    else:
        print("   ⚠️ สรุป: ความคุ้มค่าน้อยลง ผลตอบแทนอาจไม่สมน้ำสมเนื้อกับความเสี่ยงที่เผชิญ")
    print(f"   • อัตราความแม่นยำรายวัน (Win Rate): {win_rate:.2f}%")
    print("=" * 55 + "\n")

# %%
# ==========================================
# 6. HIGH-SPEED TRAINING PIPELINE WITH VALIDATION
# ==========================================
def train_model():
    TRAIN_START, TRAIN_END = '1999-01-01', '2019-12-31'
    VAL_START, VAL_END = '2020-01-01', '2023-12-31'

    os.makedirs("./exported_data", exist_ok=True)

    print(f"\nℹ️ Feature ทั้งหมดที่ใช้ ({len(FEATURES)} ตัว): {FEATURES}")
    print("\n--- 🛠️ [1/3] เริ่มเตรียมข้อมูลสําหรับฝึกสอนบอท (Training Set) ---")
    train_df = fetch_and_prepare_data(TICKERS, TRAIN_START, TRAIN_END)

    print("\n--- 🛠️ [2/3] เริ่มเตรียมข้อมูลสําหรับข้อสอบ (Validation Set) ---")
    val_df = fetch_and_prepare_data(TICKERS, VAL_START, VAL_END)

    # Scale ทั้ง Macro และ Technical (อิงจาก Train set เพื่อป้องกัน leakage)
    scaling_stats = compute_feature_scaling_stats(train_df)
    train_df = apply_feature_scaling(train_df, scaling_stats)
    val_df = apply_feature_scaling(val_df, scaling_stats)

    with open("./exported_data/feature_scaling_stats.json", "w") as f:
        json.dump({k: list(v) for k, v in scaling_stats.items()}, f)

    train_df.to_csv("./exported_data/train_set.csv", index=False)
    val_df.to_csv("./exported_data/validation_set.csv", index=False)

    env_kwargs = get_env_kwargs(len(TICKERS))
    def make_env():
        return lambda: RealisticTradingEnv(df=train_df, **env_kwargs)

    # 📌 [หมายเหตุ: สำหรับ Windows ถ้าเกิดปัญหา KeyboardInterrupt/ค้าง ให้ตั้ง NUM_CPU = 1 และใช้ DummyVecEnv เพียวๆ]
    NUM_CPU = 4
    env_train = SubprocVecEnv([make_env() for _ in range(NUM_CPU)])
    env_val = DummyVecEnv([lambda: RealisticTradingEnv(df=val_df, **env_kwargs)])

    os.makedirs("./best_model", exist_ok=True)
    eval_callback = EvalCallback(
        env_val,
        best_model_save_path='./best_model/',
        log_path='./best_model/logs/',
        eval_freq=max(500, 2048 // NUM_CPU),
        deterministic=True,
        render=False
    )

    # 📌 [แก้ตรงนี้: เปลี่ยน agent เป็น SAC และนำพารามิเตอร์ n_steps ออก]
    agent = SAC("MlpPolicy", env_train, learning_rate=0.00025, batch_size=256, device=device, verbose=1)

    print("\n--- 🚀 [3/3] บอทเริ่มกระโจนเข้าสู่การเรียนรู้แบบคู่ขนาน ---")
    try:
        # คุณน่าจะเห็น Explained Variance ขยับสูงขึ้นอย่างชัดเจนจากการรันรอบนี้
        agent.learn(total_timesteps=150_000, callback=eval_callback) 
        # 📌 [แก้ตรงนี้: เปลี่ยนชื่อไฟล์ที่บันทึกให้สอดคล้องกับ SAC]
        agent.save("sac_realistic_trading_bot_last")
        print("💾 บันทึกโมเดลเสร็จสิ้น!")
    except Exception as e:
        print(f"❌ เกิดข้อผิดพลาดในจังหวะเทรนโมเดล: {e}")

# %%
# ==========================================
# 7. COMPREHENSIVE OUT-OF-SAMPLE TEST
# ==========================================
def test_model():
    # แก้ไข #8: เผื่อระยะเวลา 4 ปี (2020) เป็น Lookback Buffer ให้ MACD Monthly มีข้อมูลพอคำนวณ
    # และเริ่มประเมินผล Test จริงในวันที่ '2024-01-01' โดยใช้พารามิเตอร์ trim_start
    FETCH_START, TEST_END = '2020-01-01', '2026-07-29'
    TRIM_START = '2024-01-01'

    print("\n🔮 ดึงข้อมูลตลาดปัจจุบันมาสับไพ่ทดสอบจริง (Out-of-Sample Test)...")
    test_df = fetch_and_prepare_data(TICKERS, FETCH_START, TEST_END, trim_start=TRIM_START)

    scaling_path = "./exported_data/feature_scaling_stats.json"
    if not os.path.exists(scaling_path):
        raise FileNotFoundError(f"⚠️ ไม่พบไฟล์ '{scaling_path}' กรุณารัน train_model() ก่อน")
    
    with open(scaling_path, "r") as f:
        scaling_stats = {k: tuple(v) for k, v in json.load(f).items()}
    test_df = apply_feature_scaling(test_df, scaling_stats)

    os.makedirs("./exported_data", exist_ok=True)
    test_df.to_csv("./exported_data/test_set.csv", index=False)

    # 📌 [แก้ตรงนี้: ปรับแก้ชื่อไฟล์ที่จะทำการโหลดให้เป็นเวอร์ชันของ SAC]
    model_path = "./best_model/best_model.zip"
    if not os.path.exists(model_path):
        model_path = "sac_realistic_trading_bot_last"

    # 📌 [แก้ตรงนี้: ปรับแก้เป็น SAC.load เพื่อให้โหลดโมเดลกลับมาถูกคลาส]
    trained_model = SAC.load(model_path, device=device)
    env_kwargs = get_env_kwargs(len(TICKERS))
    
    e_test_gym = RealisticTradingEnv(df=test_df, **env_kwargs)
    env_test = DummyVecEnv([lambda: e_test_gym])

    obs = env_test.reset()
    account_memory = []
    num_days = len(test_df.index.unique())

    print("📈 บอทกำลังดำเนินการจำลองการกระจายสินทรัพย์จริงในอดีต...")
    for i in range(num_days):
        action, _ = trained_model.predict(obs, deterministic=True)
        obs, rewards, dones, info = env_test.step(action)

        if i == num_days - 2:
            account_memory = env_test.env_method(method_name="save_asset_memory")[0]

        if dones[0]:
            print("🏁 การทดสอบย้อนหลังสิ้นสุดสมบูรณ์!")
            break

    df_account_value = pd.DataFrame(account_memory)
    df_account_value['date'] = pd.to_datetime(df_account_value['date'])
    df_account_value.set_index('date', inplace=True)
    df_account_value['daily_return'] = df_account_value['account_value'].pct_change()
    df_account_value.dropna(inplace=True)

    explain_bot_performance(df_account_value['daily_return'])

# %%
# ==========================================
# 8. EXECUTION GATEWAY
# ==========================================
if __name__ == "__main__":
    train_model()
    test_model()
# Out:
# ℹ️ Feature ทั้งหมดที่ใช้ (28 ตัว): ['RSI_14', 'RSI_signal', 'RSI_overbought', 'RSI_oversold', 'RSI_above_center', 'MACD_line_pct', 'MACD_signal_pct', 'MACD_hist_pct', 'MACD_cross', 'EMA_12_26_ratio', 'EMA_50_200_ratio', 'price_to_EMA50_ratio', 'price_to_EMA200_ratio', 'EMA_golden_cross', 'EMA_death_cross', 'StochRSI_K', 'StochRSI_D', 'StochRSI_cross', 'RSI_weekly', 'RSI_monthly', 'MACD_hist_weekly_pct', 'MACD_hist_monthly_pct', 'vix', 'bond_yield', 'gold', 'wti', 'fed_rate', 'm2']
#
# --- 🛠️ [1/3] เริ่มเตรียมข้อมูลสําหรับฝึกสอนบอท (Training Set) ---
# 📦 กําลังดาวน์โหลดข้อมูลจาก 1999-01-01 ถึง 2019-12-31...
#
# --- 🛠️ [2/3] เริ่มเตรียมข้อมูลสําหรับข้อสอบ (Validation Set) ---
# 📦 กําลังดาวน์โหลดข้อมูลจาก 2020-01-01 ถึง 2023-12-31...
# Using cpu device
#
# --- 🚀 [3/3] บอทเริ่มกระโจนเข้าสู่การเรียนรู้แบบคู่ขนาน ---
# Eval num_timesteps=2048, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 807       |
# |    mean_reward     | 44.6      |
# | time/              |           |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    actor_loss      | -1.36e+03 |
# |    critic_loss     | 103       |
# |    ent_coef        | 1.13      |
# |    ent_coef_loss   | -6.13     |
# |    learning_rate   | 0.00025   |
# |    n_updates       | 486       |
# ----------------------------------
# New best mean reward!
# day: 806, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=4096, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 4096     |
# | train/             |          |
# |    actor_loss      | -483     |
# |    critic_loss     | 167      |
# |    ent_coef        | 1.28     |
# |    ent_coef_loss   | -12.6    |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 998      |
# ---------------------------------
# Eval num_timesteps=6144, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 6144     |
# | train/             |          |
# |    actor_loss      | -167     |
# |    critic_loss     | 143      |
# |    ent_coef        | 1.46     |
# |    ent_coef_loss   | -19.1    |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 1510     |
# ---------------------------------
# day: 806, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=8192, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 8192     |
# | train/             |          |
# |    actor_loss      | 321      |
# |    critic_loss     | 95.7     |
# |    ent_coef        | 1.66     |
# |    ent_coef_loss   | -25.6    |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 2022     |
# ---------------------------------
# Eval num_timesteps=10240, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 10240    |
# | train/             |          |
# |    actor_loss      | 743      |
# |    critic_loss     | 79.2     |
# |    ent_coef        | 1.88     |
# |    ent_coef_loss   | -32.1    |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 2534     |
# ---------------------------------
# Eval num_timesteps=12288, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 12288    |
# | train/             |          |
# |    actor_loss      | 1.11e+03 |
# |    critic_loss     | 81.6     |
# |    ent_coef        | 2.14     |
# |    ent_coef_loss   | -38.5    |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 3046     |
# ---------------------------------
# day: 806, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=14336, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 14336    |
# | train/             |          |
# |    actor_loss      | 1.35e+03 |
# |    critic_loss     | 28.7     |
# |    ent_coef        | 2.43     |
# |    ent_coef_loss   | -45      |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 3558     |
# ---------------------------------
# Eval num_timesteps=16384, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 16384    |
# | train/             |          |
# |    actor_loss      | 1.72e+03 |
# |    critic_loss     | 69.8     |
# |    ent_coef        | 2.77     |
# |    ent_coef_loss   | -51.4    |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 4070     |
# ---------------------------------
# day: 806, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=18432, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 18432    |
# | train/             |          |
# |    actor_loss      | 2.25e+03 |
# |    critic_loss     | 28.1     |
# |    ent_coef        | 3.14     |
# |    ent_coef_loss   | -58      |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 4582     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 93       |
# |    time_elapsed    | 207      |
# |    total_timesteps | 19452    |
# | train/             |          |
# |    actor_loss      | 2.39e+03 |
# |    critic_loss     | 19.6     |
# |    ent_coef        | 3.35     |
# |    ent_coef_loss   | -61.3    |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 4837     |
# ---------------------------------
# Eval num_timesteps=20480, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 20480    |
# | train/             |          |
# |    actor_loss      | 2.53e+03 |
# |    critic_loss     | 137      |
# |    ent_coef        | 3.57     |
# |    ent_coef_loss   | -64.6    |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 5094     |
# ---------------------------------
# Eval num_timesteps=22528, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 22528    |
# | train/             |          |
# |    actor_loss      | 3e+03    |
# |    critic_loss     | 73.2     |
# |    ent_coef        | 4.06     |
# |    ent_coef_loss   | -71.2    |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 5606     |
# ---------------------------------
# day: 806, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=24576, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 24576    |
# | train/             |          |
# |    actor_loss      | 3.54e+03 |
# |    critic_loss     | 143      |
# |    ent_coef        | 4.61     |
# |    ent_coef_loss   | -77.5    |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 6118     |
# ---------------------------------
# Eval num_timesteps=26624, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 26624    |
# | train/             |          |
# |    actor_loss      | 4.11e+03 |
# |    critic_loss     | 186      |
# |    ent_coef        | 5.24     |
# |    ent_coef_loss   | -84.1    |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 6630     |
# ---------------------------------
# day: 806, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=28672, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 28672    |
# | train/             |          |
# |    actor_loss      | 4.83e+03 |
# |    critic_loss     | 306      |
# |    ent_coef        | 5.96     |
# |    ent_coef_loss   | -90.4    |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 7142     |
# ---------------------------------
# Eval num_timesteps=30720, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 30720    |
# | train/             |          |
# |    actor_loss      | 5.58e+03 |
# |    critic_loss     | 1.63e+03 |
# |    ent_coef        | 6.77     |
# |    ent_coef_loss   | -97      |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 7654     |
# ---------------------------------
# Eval num_timesteps=32768, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 32768    |
# | train/             |          |
# |    actor_loss      | 6.44e+03 |
# |    critic_loss     | 6.15e+03 |
# |    ent_coef        | 7.7      |
# |    ent_coef_loss   | -104     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 8166     |
# ---------------------------------
# day: 806, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=34816, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 34816    |
# | train/             |          |
# |    actor_loss      | 7.52e+03 |
# |    critic_loss     | 142      |
# |    ent_coef        | 8.75     |
# |    ent_coef_loss   | -110     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 8678     |
# ---------------------------------
# Eval num_timesteps=36864, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 36864    |
# | train/             |          |
# |    actor_loss      | 8.57e+03 |
# |    critic_loss     | 104      |
# |    ent_coef        | 9.95     |
# |    ent_coef_loss   | -117     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 9190     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 92       |
# |    time_elapsed    | 420      |
# |    total_timesteps | 38904    |
# | train/             |          |
# |    actor_loss      | 9.93e+03 |
# |    critic_loss     | 447      |
# |    ent_coef        | 11.3     |
# |    ent_coef_loss   | -123     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 9700     |
# ---------------------------------
# day: 806, episode: 110
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=38912, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 38912    |
# | train/             |          |
# |    actor_loss      | 9.93e+03 |
# |    critic_loss     | 436      |
# |    ent_coef        | 11.3     |
# |    ent_coef_loss   | -123     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 9702     |
# ---------------------------------
# Eval num_timesteps=40960, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 40960    |
# | train/             |          |
# |    actor_loss      | 1.15e+04 |
# |    critic_loss     | 755      |
# |    ent_coef        | 12.8     |
# |    ent_coef_loss   | -130     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 10214    |
# ---------------------------------
# Eval num_timesteps=43008, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 43008    |
# | train/             |          |
# |    actor_loss      | 1.33e+04 |
# |    critic_loss     | 550      |
# |    ent_coef        | 14.6     |
# |    ent_coef_loss   | -136     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 10726    |
# ---------------------------------
# day: 806, episode: 130
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=45056, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 45056    |
# | train/             |          |
# |    actor_loss      | 1.51e+04 |
# |    critic_loss     | 405      |
# |    ent_coef        | 16.6     |
# |    ent_coef_loss   | -142     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 11238    |
# ---------------------------------
# Eval num_timesteps=47104, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 47104    |
# | train/             |          |
# |    actor_loss      | 1.74e+04 |
# |    critic_loss     | 875      |
# |    ent_coef        | 18.9     |
# |    ent_coef_loss   | -149     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 11750    |
# ---------------------------------
# day: 806, episode: 140
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=49152, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 49152    |
# | train/             |          |
# |    actor_loss      | 1.98e+04 |
# |    critic_loss     | 3.6e+03  |
# |    ent_coef        | 21.4     |
# |    ent_coef_loss   | -155     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 12262    |
# ---------------------------------
# Eval num_timesteps=51200, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 51200    |
# | train/             |          |
# |    actor_loss      | 2.27e+04 |
# |    critic_loss     | 1.81e+06 |
# |    ent_coef        | 24.4     |
# |    ent_coef_loss   | -162     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 12774    |
# ---------------------------------
# Eval num_timesteps=53248, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 53248    |
# | train/             |          |
# |    actor_loss      | 2.59e+04 |
# |    critic_loss     | 1.35e+03 |
# |    ent_coef        | 27.7     |
# |    ent_coef_loss   | -168     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 13286    |
# ---------------------------------
# day: 806, episode: 160
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=55296, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 55296    |
# | train/             |          |
# |    actor_loss      | 2.96e+04 |
# |    critic_loss     | 1.78e+03 |
# |    ent_coef        | 31.5     |
# |    ent_coef_loss   | -175     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 13798    |
# ---------------------------------
# Eval num_timesteps=57344, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 57344    |
# | train/             |          |
# |    actor_loss      | 3.38e+04 |
# |    critic_loss     | 1.35e+03 |
# |    ent_coef        | 35.8     |
# |    ent_coef_loss   | -181     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 14310    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 90       |
# |    time_elapsed    | 641      |
# |    total_timesteps | 58356    |
# | train/             |          |
# |    actor_loss      | 3.62e+04 |
# |    critic_loss     | 3.13e+04 |
# |    ent_coef        | 38.1     |
# |    ent_coef_loss   | -185     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 14563    |
# ---------------------------------
# day: 806, episode: 170
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=59392, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 59392    |
# | train/             |          |
# |    actor_loss      | 3.86e+04 |
# |    critic_loss     | 1.83e+04 |
# |    ent_coef        | 40.7     |
# |    ent_coef_loss   | -188     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 14822    |
# ---------------------------------
# Eval num_timesteps=61440, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 61440    |
# | train/             |          |
# |    actor_loss      | 4.41e+04 |
# |    critic_loss     | 7.75e+04 |
# |    ent_coef        | 46.2     |
# |    ent_coef_loss   | -194     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 15334    |
# ---------------------------------
# Eval num_timesteps=63488, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 63488    |
# | train/             |          |
# |    actor_loss      | 5.03e+04 |
# |    critic_loss     | 2.19e+04 |
# |    ent_coef        | 52.5     |
# |    ent_coef_loss   | -201     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 15846    |
# ---------------------------------
# day: 806, episode: 190
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=65536, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 65536    |
# | train/             |          |
# |    actor_loss      | 5.72e+04 |
# |    critic_loss     | 6.14e+03 |
# |    ent_coef        | 59.7     |
# |    ent_coef_loss   | -208     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 16358    |
# ---------------------------------
# Eval num_timesteps=67584, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 67584    |
# | train/             |          |
# |    actor_loss      | 6.53e+04 |
# |    critic_loss     | 7.66e+04 |
# |    ent_coef        | 67.8     |
# |    ent_coef_loss   | -213     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 16870    |
# ---------------------------------
# day: 806, episode: 200
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=69632, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 69632    |
# | train/             |          |
# |    actor_loss      | 7.37e+04 |
# |    critic_loss     | 3.93e+05 |
# |    ent_coef        | 77.1     |
# |    ent_coef_loss   | -220     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 17382    |
# ---------------------------------
# Eval num_timesteps=71680, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 71680    |
# | train/             |          |
# |    actor_loss      | 8.42e+04 |
# |    critic_loss     | 2.38e+07 |
# |    ent_coef        | 87.6     |
# |    ent_coef_loss   | -227     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 17894    |
# ---------------------------------
# Eval num_timesteps=73728, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 73728    |
# | train/             |          |
# |    actor_loss      | 9.58e+04 |
# |    critic_loss     | 1.23e+05 |
# |    ent_coef        | 99.6     |
# |    ent_coef_loss   | -233     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 18406    |
# ---------------------------------
# day: 806, episode: 220
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=75776, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 75776    |
# | train/             |          |
# |    actor_loss      | 1.09e+05 |
# |    critic_loss     | 1.72e+04 |
# |    ent_coef        | 113      |
# |    ent_coef_loss   | -239     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 18918    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 90       |
# |    time_elapsed    | 857      |
# |    total_timesteps | 77808    |
# | train/             |          |
# |    actor_loss      | 1.24e+05 |
# |    critic_loss     | 4.05e+04 |
# |    ent_coef        | 128      |
# |    ent_coef_loss   | -246     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 19426    |
# ---------------------------------
# Eval num_timesteps=77824, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 77824    |
# | train/             |          |
# |    actor_loss      | 1.25e+05 |
# |    critic_loss     | 4.92e+04 |
# |    ent_coef        | 129      |
# |    ent_coef_loss   | -246     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 19430    |
# ---------------------------------
# day: 806, episode: 230
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=79872, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 79872    |
# | train/             |          |
# |    actor_loss      | 1.41e+05 |
# |    critic_loss     | 6.67e+07 |
# |    ent_coef        | 146      |
# |    ent_coef_loss   | -253     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 19942    |
# ---------------------------------
# Eval num_timesteps=81920, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 81920    |
# | train/             |          |
# |    actor_loss      | 1.6e+05  |
# |    critic_loss     | 1.14e+05 |
# |    ent_coef        | 166      |
# |    ent_coef_loss   | -259     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 20454    |
# ---------------------------------
# Eval num_timesteps=83968, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 83968    |
# | train/             |          |
# |    actor_loss      | 1.82e+05 |
# |    critic_loss     | 3.59e+05 |
# |    ent_coef        | 189      |
# |    ent_coef_loss   | -266     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 20966    |
# ---------------------------------
# day: 806, episode: 250
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=86016, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 86016    |
# | train/             |          |
# |    actor_loss      | 2.08e+05 |
# |    critic_loss     | 1.09e+05 |
# |    ent_coef        | 215      |
# |    ent_coef_loss   | -272     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 21478    |
# ---------------------------------
# Eval num_timesteps=88064, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 88064    |
# | train/             |          |
# |    actor_loss      | 2.37e+05 |
# |    critic_loss     | 1.2e+05  |
# |    ent_coef        | 244      |
# |    ent_coef_loss   | -278     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 21990    |
# ---------------------------------
# day: 806, episode: 260
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=90112, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 90112    |
# | train/             |          |
# |    actor_loss      | 2.68e+05 |
# |    critic_loss     | 1.48e+06 |
# |    ent_coef        | 277      |
# |    ent_coef_loss   | -285     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 22502    |
# ---------------------------------
# Eval num_timesteps=92160, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 92160    |
# | train/             |          |
# |    actor_loss      | 3.05e+05 |
# |    critic_loss     | 3.56e+05 |
# |    ent_coef        | 315      |
# |    ent_coef_loss   | -292     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 23014    |
# ---------------------------------
# Eval num_timesteps=94208, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 94208    |
# | train/             |          |
# |    actor_loss      | 3.46e+05 |
# |    critic_loss     | 1.4e+06  |
# |    ent_coef        | 358      |
# |    ent_coef_loss   | -299     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 23526    |
# ---------------------------------
# day: 806, episode: 280
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=96256, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 96256    |
# | train/             |          |
# |    actor_loss      | 3.94e+05 |
# |    critic_loss     | 1.63e+06 |
# |    ent_coef        | 407      |
# |    ent_coef_loss   | -305     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 24038    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 89       |
# |    time_elapsed    | 1085     |
# |    total_timesteps | 97260    |
# | train/             |          |
# |    actor_loss      | 4.22e+05 |
# |    critic_loss     | 1.05e+06 |
# |    ent_coef        | 433      |
# |    ent_coef_loss   | -307     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 24289    |
# ---------------------------------
# Eval num_timesteps=98304, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 98304    |
# | train/             |          |
# |    actor_loss      | 4.49e+05 |
# |    critic_loss     | 3.57e+05 |
# |    ent_coef        | 462      |
# |    ent_coef_loss   | -310     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 24550    |
# ---------------------------------
# day: 806, episode: 290
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=100352, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 100352   |
# | train/             |          |
# |    actor_loss      | 5.1e+05  |
# |    critic_loss     | 5.52e+05 |
# |    ent_coef        | 525      |
# |    ent_coef_loss   | -317     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 25062    |
# ---------------------------------
# Eval num_timesteps=102400, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 102400   |
# | train/             |          |
# |    actor_loss      | 5.81e+05 |
# |    critic_loss     | 6.21e+05 |
# |    ent_coef        | 597      |
# |    ent_coef_loss   | -324     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 25574    |
# ---------------------------------
# Eval num_timesteps=104448, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 104448   |
# | train/             |          |
# |    actor_loss      | 6.59e+05 |
# |    critic_loss     | 7.95e+05 |
# |    ent_coef        | 679      |
# |    ent_coef_loss   | -330     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 26086    |
# ---------------------------------
# day: 806, episode: 310
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=106496, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 106496   |
# | train/             |          |
# |    actor_loss      | 7.5e+05  |
# |    critic_loss     | 7.09e+05 |
# |    ent_coef        | 771      |
# |    ent_coef_loss   | -336     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 26598    |
# ---------------------------------
# Eval num_timesteps=108544, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 108544   |
# | train/             |          |
# |    actor_loss      | 8.53e+05 |
# |    critic_loss     | 1.9e+06  |
# |    ent_coef        | 877      |
# |    ent_coef_loss   | -343     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 27110    |
# ---------------------------------
# day: 806, episode: 320
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=110592, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 110592   |
# | train/             |          |
# |    actor_loss      | 9.69e+05 |
# |    critic_loss     | 3.25e+06 |
# |    ent_coef        | 996      |
# |    ent_coef_loss   | -350     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 27622    |
# ---------------------------------
# Eval num_timesteps=112640, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 112640   |
# | train/             |          |
# |    actor_loss      | 1.1e+06  |
# |    critic_loss     | 2.18e+06 |
# |    ent_coef        | 1.13e+03 |
# |    ent_coef_loss   | -357     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 28134    |
# ---------------------------------
# Eval num_timesteps=114688, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 114688   |
# | train/             |          |
# |    actor_loss      | 1.25e+06 |
# |    critic_loss     | 8.19e+06 |
# |    ent_coef        | 1.29e+03 |
# |    ent_coef_loss   | -363     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 28646    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 92       |
# |    time_elapsed    | 1255     |
# |    total_timesteps | 116712   |
# | train/             |          |
# |    actor_loss      | 1.42e+06 |
# |    critic_loss     | 7.24e+06 |
# |    ent_coef        | 1.46e+03 |
# |    ent_coef_loss   | -369     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 29152    |
# ---------------------------------
# day: 806, episode: 340
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=116736, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 116736   |
# | train/             |          |
# |    actor_loss      | 1.42e+06 |
# |    critic_loss     | 1.97e+07 |
# |    ent_coef        | 1.46e+03 |
# |    ent_coef_loss   | -369     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 29158    |
# ---------------------------------
# Eval num_timesteps=118784, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 118784   |
# | train/             |          |
# |    actor_loss      | 1.62e+06 |
# |    critic_loss     | 7.32e+06 |
# |    ent_coef        | 1.66e+03 |
# |    ent_coef_loss   | -376     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 29670    |
# ---------------------------------
# day: 806, episode: 350
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=120832, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 120832   |
# | train/             |          |
# |    actor_loss      | 1.84e+06 |
# |    critic_loss     | 4.71e+06 |
# |    ent_coef        | 1.89e+03 |
# |    ent_coef_loss   | -382     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 30182    |
# ---------------------------------
# Eval num_timesteps=122880, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 122880   |
# | train/             |          |
# |    actor_loss      | 2.09e+06 |
# |    critic_loss     | 1.51e+07 |
# |    ent_coef        | 2.15e+03 |
# |    ent_coef_loss   | -390     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 30694    |
# ---------------------------------
# Eval num_timesteps=124928, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 124928   |
# | train/             |          |
# |    actor_loss      | 2.37e+06 |
# |    critic_loss     | 1.55e+07 |
# |    ent_coef        | 2.44e+03 |
# |    ent_coef_loss   | -395     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 31206    |
# ---------------------------------
# day: 806, episode: 370
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=126976, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 126976   |
# | train/             |          |
# |    actor_loss      | 2.7e+06  |
# |    critic_loss     | 2.83e+07 |
# |    ent_coef        | 2.77e+03 |
# |    ent_coef_loss   | -401     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 31718    |
# ---------------------------------
# Eval num_timesteps=129024, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 129024   |
# | train/             |          |
# |    actor_loss      | 3.06e+06 |
# |    critic_loss     | 1.74e+07 |
# |    ent_coef        | 3.15e+03 |
# |    ent_coef_loss   | -409     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 32230    |
# ---------------------------------
# day: 806, episode: 380
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=131072, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 131072   |
# | train/             |          |
# |    actor_loss      | 3.48e+06 |
# |    critic_loss     | 1.05e+08 |
# |    ent_coef        | 3.58e+03 |
# |    ent_coef_loss   | -416     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 32742    |
# ---------------------------------
# Eval num_timesteps=133120, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 133120   |
# | train/             |          |
# |    actor_loss      | 3.96e+06 |
# |    critic_loss     | 2.76e+07 |
# |    ent_coef        | 4.07e+03 |
# |    ent_coef_loss   | -421     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 33254    |
# ---------------------------------
# Eval num_timesteps=135168, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 135168   |
# | train/             |          |
# |    actor_loss      | 4.5e+06  |
# |    critic_loss     | 4.45e+07 |
# |    ent_coef        | 4.63e+03 |
# |    ent_coef_loss   | -428     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 33766    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 94       |
# |    time_elapsed    | 1446     |
# |    total_timesteps | 136164   |
# | train/             |          |
# |    actor_loss      | 4.79e+06 |
# |    critic_loss     | 2.12e+07 |
# |    ent_coef        | 4.92e+03 |
# |    ent_coef_loss   | -430     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 34015    |
# ---------------------------------
# day: 806, episode: 400
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=137216, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 137216   |
# | train/             |          |
# |    actor_loss      | 5.11e+06 |
# |    critic_loss     | 5.64e+07 |
# |    ent_coef        | 5.26e+03 |
# |    ent_coef_loss   | -435     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 34278    |
# ---------------------------------
# Eval num_timesteps=139264, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 139264   |
# | train/             |          |
# |    actor_loss      | 5.82e+06 |
# |    critic_loss     | 1.96e+08 |
# |    ent_coef        | 5.97e+03 |
# |    ent_coef_loss   | -441     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 34790    |
# ---------------------------------
# day: 806, episode: 410
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=141312, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 141312   |
# | train/             |          |
# |    actor_loss      | 6.59e+06 |
# |    critic_loss     | 4.84e+07 |
# |    ent_coef        | 6.79e+03 |
# |    ent_coef_loss   | -447     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 35302    |
# ---------------------------------
# Eval num_timesteps=143360, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 143360   |
# | train/             |          |
# |    actor_loss      | 7.5e+06  |
# |    critic_loss     | 9.35e+07 |
# |    ent_coef        | 7.72e+03 |
# |    ent_coef_loss   | -453     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 35814    |
# ---------------------------------
# Eval num_timesteps=145408, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 145408   |
# | train/             |          |
# |    actor_loss      | 8.51e+06 |
# |    critic_loss     | 4.89e+11 |
# |    ent_coef        | 8.77e+03 |
# |    ent_coef_loss   | -460     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 36326    |
# ---------------------------------
# day: 806, episode: 430
# begin_total_asset: 1000000.00
# end_total_asset: 1448892.12
# total_reward: 448892.12
# total_cost: 2990.57
# total_trades: 1612
# Sharpe: 0.805
# =================================
# Eval num_timesteps=147456, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 147456   |
# | train/             |          |
# |    actor_loss      | 9.68e+06 |
# |    critic_loss     | 1.42e+08 |
# |    ent_coef        | 9.97e+03 |
# |    ent_coef_loss   | -468     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 36838    |
# ---------------------------------
# Eval num_timesteps=149504, episode_reward=44.62 +/- 0.00
# Episode length: 807.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 807      |
# |    mean_reward     | 44.6     |
# | time/              |          |
# |    total_timesteps | 149504   |
# | train/             |          |
# |    actor_loss      | 1.1e+07  |
# |    critic_loss     | 3.22e+08 |
# |    ent_coef        | 1.13e+04 |
# |    ent_coef_loss   | -473     |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 37350    |
# ---------------------------------
# 💾 บันทึกโมเดลเสร็จสิ้น!
#
# 🔮 ดึงข้อมูลตลาดปัจจุบันมาสับไพ่ทดสอบจริง (Out-of-Sample Test)...
# 📦 กําลังดาวน์โหลดข้อมูลจาก 2020-01-01 ถึง 2026-07-29...
# ✂️ หั่น Lookback Buffer ทิ้ง เหลือข้อมูลใช้งานจริงตั้งแต่: 2024-01-01
# 📈 บอทกำลังดำเนินการจำลองการกระจายสินทรัพย์จริงในอดีต...
# 🏁 การทดสอบย้อนหลังสิ้นสุดสมบูรณ์!
#
# =======================================================
# 🤖 สรุปผลงานบอทเทรดในหน้าต่างทดสอบจริง (ฉบับเข้าใจง่าย)
# =======================================================
#
# 💰 1. ด้านการทำกำไร (Return)
#    • กำไรสะสมตลอดการทดสอบ: 54.21%
#    • ผลตอบแทนทบต้นเฉลี่ยรายปี (CAGR): 18.50%
#    ✅ สรุป: ยอดเยี่ยม! บอทสร้างผลงานชนะอัตราเฉลี่ยของตลาดส่วนใหญ่
#
# 📉 2. ด้านความเสี่ยง (Risk & Drawdown)
#    • ช่วงที่พอร์ตร่วงหนักสุดจากจุดสูงสุด (Max Drawdown): -17.38%
#    ⚠️ สรุป: ปานกลาง พอร์ตแกว่งตามมาตรฐานสไตล์กองทุนเชิงรุก
#
# ⚖️ 3. ความคุ้มค่าและสถิติการชนะ (Efficiency)
#    • ความคุ้มค่าต่อหนึ่งหน่วยความเสี่ยง (Sharpe Ratio): 1.23
#    ✅ สรุป: ดีเยี่ยม กำไรที่ได้คุ้มค่าอย่างมากกับความเสี่ยงที่ถือครอง
#    • อัตราความแม่นยำรายวัน (Win Rate): 55.21%
# =======================================================
